# %%
import numpy as np
from sklearn import preprocessing

# %%
def step_gradient(points, learning_rate,m):
    m_slope = [0 for i in range(len(m))]
    M = len(points)
    for i in range(len(points)):
        y = points[i,len(m)]
        temp_m = 0
        for j in range(len(m)):
            x = points[i,j]
            temp_m+=m[j]*x
        for j in range(len(m)):
            x = points[i,j]
            m_slope[j]+=(-2/M) * (y-temp_m)*x
    new_m = [0 for i in range(len(m))]
    for j in range(len(m)):
        new_m[j] = m[j] - learning_rate*m_slope[j]
    return new_m

# %%
def gd(points,learning_rate,num_iterations,nf):
    # start with random value of m, c
    m = [0 for i in range(nf+1)]
    for i in range(num_iterations):
        m = step_gradient(points,learning_rate,m)
        print(i, " Cost: ", cost(points,m))
    return m

# %%
def cost(points, m):
    M = len(points)
    total_cost = 0
    for i in range(M):
        y = points[i,len(m)]
        cost_temp = 0
        for j in range(len(m)):
            x = points[i,j]
            cost_temp += m[j]*x
        total_cost += (1/M)*((y-cost_temp)**2)
    return total_cost

# %%
def scale(points,scale):
    scale = preprocessing.StandardScale()
    scale.fit(points)
    return points

# %%
def pred(test_points, m):
    M = len(m)
    Y = [0 for i in range(len(test_points))]
    for i in range(len(test_points)):
        temp_y = 0
        for j in range(M-1):
            temp_y +=test_points[i,j]*m[j]
        temp_y+=m[M-1]
        Y[i] = temp_y
    return Y

# %%
def run():
    data = np.loadtxt("0000000000002419_training_ccpp_x_y_train.csv",delimiter=",")
    print(data.shape)
    num_features = 4
    data1 = data[:,:num_features]
    new_column = [[1] for i in range(len(data))]
    scaler = preprocessing.StandardScaler()
    scaler.fit(data1)
    data1 = scaler.transform(data1)
    data1 = np.append(data1,new_column,axis=1)
    y_column = [[i] for i in data[:,num_features]]
    data1 = np.append(data1,y_column,axis=1)
#     learning_rate = 0.00000085 # without scaling
    learning_rate = 0.00000001 # with scaling
    num_iterations = 1000
    m = gd(data1,learning_rate,num_iterations,num_features)
    print(len(m),m)
    print(data1.shape)
#     test_data = np.loadtxt("0000000000002419_test_ccpp_x_test.csv",delimiter=",")
#     print(test_data.shape,m)
#     test_data = scaler.transform(test_data)
#     pred_data = pred(test_data,m)
#     print(pred)
#     np.savetxt("0000000000002419_pred.csv",pred_data,delimiter=",",fmt='%f')

# %%
run()
# Out:
# (7176, 5)
# 0  Cost:  206800.64865267344
# 1  Cost:  206799.94445262398
# 2  Cost:  206799.2402549773
# 3  Cost:  206798.53605973613
# 4  Cost:  206797.83186689785
# 5  Cost:  206797.12767646599
# 6  Cost:  206796.4234884361
# 7  Cost:  206795.7193028106
# 8  Cost:  206795.01511958943
# 9  Cost:  206794.3109387737
# 10  Cost:  206793.60676036164
# 11  Cost:  206792.90258435308
# 12  Cost:  206792.19841074845
# 13  Cost:  206791.49423954927
# 14  Cost:  206790.79007075282
# 15  Cost:  206790.08590436235
# 16  Cost:  206789.38174037484
# 17  Cost:  206788.67757878927
# 363  Cost:  206545.18193537873
# 364  Cost:  206544.47860752748
# 365  Cost:  206543.7752820776
# 366  Cost:  206543.0719590294
# 367  Cost:  206542.36863838183
# 368  Cost:  206541.66532013705
# 369  Cost:  206540.9620042907
# 370  Cost:  206540.25869084767
# 371  Cost:  206539.5553798052
# 372  Cost:  206538.85207116426
# 373  Cost:  206538.14876492467
# 374  Cost:  206537.44546108457
# 375  Cost:  206536.74215964746
# 376  Cost:  206536.0388606108
# 377  Cost:  206535.3355639748
# 378  Cost:  206534.6322697412
# 379  Cost:  206533.9289779073
# 380  Cost:  206533.22568847577
# 381  Cost:  206532.52240144412
# 382  Cost:  206531.81911681473
# 383  Cost:  206531.11583458586
# 384  Cost:  206530.4125547587
# 385  Cost:  206529.70927733273
# 386  Cost:  206529.00600230723
# 387  Cost:  206528.3027296828
# 388  Cost:  206527.5994594594
# 389  Cost:  206526.89619163674
# 390  Cost:  206526.19292621588
# 391  Cost:  206525.489663195
# 392  Cost:  206524.78640257672
# 393  Cost:  206524.0831443583
# 394  Cost:  206523.37988854124
# 395  Cost:  206522.6766351253
# 396  Cost:  206521.97338410933
# 397  Cost:  206521.27013549616
# 398  Cost:  206520.56688928194
# 399  Cost:  206519.8636454707
# 400  Cost:  206519.16040406
# 401  Cost:  206518.4571650489
# 402  Cost:  206517.7539284404
# 403  Cost:  206517.05069423086
# 404  Cost:  206516.34746242408
# 405  Cost:  206515.64423301796
# 406  Cost:  206514.94100601194
# 407  Cost:  206514.23778140757
# 408  Cost:  206513.53455920305
# 409  Cost:  206512.83133940081
# 410  Cost:  206512.12812199784
# 411  Cost:  206511.4249069976
# 412  Cost:  206510.72169439695
# 413  Cost:  206510.01848419782
# 414  Cost:  206509.3152763985
# 415  Cost:  206508.61207100144
# 416  Cost:  206507.90886800506
# 417  Cost:  206507.20566740798
# 418  Cost:  206506.5024692125
# 419  Cost:  206505.79927341756
# 420  Cost:  206505.09608002484
# 421  Cost:  206504.3928890318
# 422  Cost:  206503.68970044015
# 423  Cost:  206502.9865142487
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-ec9775ede022> in <module>
# ----> 1 run()
#
# <ipython-input-70-9e32c337e504> in run()
#      13     learning_rate = 0.00000085
#      14     num_iterations = 1000
# ---> 15     m = gd(data1,learning_rate,num_iterations,num_features)
#      16     print(len(m),m)
#      17     print(data1.shape)
#
# <ipython-input-15-03402b3c4ba1> in gd(points, learning_rate, num_iterations, nf)
#       3     m = [0 for i in range(nf+1)]
#       4     for i in range(num_iterations):
# ----> 5         m = step_gradient(points,learning_rate,m)
#       6         print(i, " Cost: ", cost(points,m))
#       7     return m
#
# <ipython-input-14-2ddfaa88c33b> in step_gradient(points, learning_rate, m)
#       9             temp_m+=m[j]*x
#      10         for j in range(len(m)):
# ---> 11             x = points[i,j]
#      12             m_slope[j]+=(-2/M) * (y-temp_m)*x
#      13     new_m = [0 for i in range(len(m))]
#
# KeyboardInterrupt:
