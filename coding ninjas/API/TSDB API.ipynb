# %%
# API Key 465eecab44c8ee8bb183fa7e2232c87b
# API Access Token eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0NjVlZWNhYjQ0YzhlZThiYjE4M2ZhN2UyMjMyYzg3YiIsInN1YiI6IjYxODc3M2UyMWM2YWE3MDA4OTc1MmE5MiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.MDsWkCuIpG5NGEpo9lSIuRaOg-JyvsjoUNlcDpGygyc
# https://api.themoviedb.org/3/movie/550?api_key=
import requests
import json

# %%
param ={'api_key':'465eecab44c8ee8bb183fa7e2232c87b','query':'Money Heist'}
r = requests.get('https://api.themoviedb.org/3/search/tv',verify=False,params=param)
id = r.json()['results'][0]['id']
r = requests.get('https://api.themoviedb.org/3/tv/'+str(id)+'/credits',verify=False,params=param)
m = 0
f = 0
for i in r.json()['cast']:
    if i['gender'] ==2:
        m+=1
    if i['gender'] == 1:
        f+=1
print(m,end=' ')
print(f)
r.json()
# Out:
# [{'backdrop_path': '/gFZriCkpJYsApPZEF3jhxL4yLzG.jpg', 'first_air_date': '2017-05-02', 'genre_ids': [80, 18], 'id': 71446, 'name': 'Money Heist', 'origin_country': ['ES'], 'original_language': 'es', 'original_name': 'La Casa de Papel', 'overview': 'To carry out the biggest heist in history, a mysterious man called The Professor recruits a band of eight robbers who have a single characteristic: none of them has anything to lose. Five months of seclusion - memorizing every step, every detail, every probability - culminate in eleven days locked up in the National Coinage and Stamp Factory of Spain, surrounded by police forces and with dozens of hostages in their power, to find out whether their suicide wager will lead to everything or nothing.', 'popularity': 599.923, 'poster_path': '/reEMJA1uzscCbkpeRJeTT2bjqUp.jpg', 'vote_average': 8.3, 'vote_count': 14861}, {'backdrop_path': '/bVUiZVA8iPwdEc0lX5nwEr6MwdM.jpg', 'first_air_date': '2021-09-03', 'genre_ids': [99], 'id': 132719, 'name': 'Money Heist: From Tokyo to Berlin', 'origin_country': ['ES'], 'original_language': 'es', 'original_name': 'La Casa de Papel: de Tokio a Berlín', 'overview': 'The filmmakers and actors behind "Money Heist" characters like Tokyo and the Professor talk about the emotional and artistic process of filming Money Heist.', 'popularity': 141.222, 'poster_path': '/g0wLsOFpvK5nX5hsIAwXHrpnFLI.jpg', 'vote_average': 7.3, 'vote_count': 17}, {'backdrop_path': None, 'first_air_date': '', 'genre_ids': [18], 'id': 112836, 'name': 'Money Heist', 'origin_country': ['KR'], 'original_language': 'ko', 'original_name': '종이의 집', 'overview': 'A criminal mastermind, who goes by the nickname "The Professor", has a plan to pull off the biggest heist in recorded history.\n\nThe Professor schemes an ambitious heist that will have a massive payout. For his plan, the Professor scouts for potential team members. The recruited members select city names as their code names and they all have strong personalities. Their plan seems perfect, but due to the hostages that they take, they face an unexpected situation.', 'popularity': 1.853, 'poster_path': '/s5eEB4VAvaQTLhQjrd2lGvk5yRG.jpg', 'vote_average': 0, 'vote_count': 0}]
# 11 6
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'cast': [{'adult': False,
#    'gender': 2,
#    'id': 1340020,
#    'known_for_department': 'Acting',
#    'name': 'Álvaro Morte',
#    'original_name': 'Álvaro Morte',
#    'popularity': 4.529,
#    'profile_path': '/2TGPhdpRC5wjdFEJqnLYiN5kbwg.jpg',
#    'character': 'Sergio "El Profesor" Marquina/Salvador "Salva" Martin',
#    'credit_id': '5d3376536a300b1834ac44e5',
#    'order': 0},
#   {'adult': False,
#    'gender': 1,
#    'id': 947514,
#    'known_for_department': 'Acting',
#    'name': 'Itziar Ituño',
#    'original_name': 'Itziar Ituño',
#    'popularity': 8.772,
#    'profile_path': '/vnrfL03NwRJ1X82esSNUoYzASGr.jpg',
#    'character': 'Raquel "Lisboa" Murillo',
#    'credit_id': '5a4225d29251411fab04d6ea',
#    'order': 1},
#   {'adult': False,
#    'gender': 1,
#    'id': 1042728,
#    'known_for_department': 'Acting',
#    'name': 'Úrsula Corberó',
#    'original_name': 'Úrsula Corberó',
#    'popularity': 23.343,
#    'profile_path': '/wfy2YBmaGkH5kl60y3P03tTAMMc.jpg',
#    'character': 'Silene "Tokio" Oliveira',
#    'credit_id': '5a422574c3a36858c5036f41',
#    'order': 2},
#   {'adult': False,
#    'gender': 1,
#    'id': 1283843,
#    'known_for_department': 'Acting',
#    'name': 'Alba Flores',
#    'original_name': 'Alba Flores',
#    'popularity': 9.276,
#    'profile_path': '/9ExASXw097MyNuSy6N23fpkqpXq.jpg',
#    'character': 'Ágata «Nairobi» Jiménez',
#    'credit_id': '618616fb5545ca00953deb5a',
#    'order': 3},
#   {'adult': False,
#    'gender': 2,
#    'id': 1109836,
#    'known_for_department': 'Acting',
#    'name': 'Pedro Alonso',
#    'original_name': 'Pedro Alonso',
#    'popularity': 6.126,
#    'profile_path': '/38HeVKeOBztVYrLJOWzAtEZiB02.jpg',
#    'character': 'Andrés "Berlin" de Fonollosa',
#    'credit_id': '5d34b7bd17792c0012bcac8d',
#    'order': 4},
#   {'adult': False,
#    'gender': 2,
#    'id': 1972706,
#    'known_for_department': 'Acting',
#    'name': 'Jaime Lorente',
#    'original_name': 'Jaime Lorente',
#    'popularity': 6.183,
#    'profile_path': '/nLaxzU92z14FIbe25sE8jDMIThZ.jpg',
#    'character': 'Dani "Denver" Ramos',
#    'credit_id': '5a773f46c3a3682273001229',
#    'order': 5},
#   {'adult': False,
#    'gender': 2,
#    'id': 1428896,
#    'known_for_department': 'Acting',
#    'name': 'Miguel Herrán',
#    'original_name': 'Miguel Herrán',
#    'popularity': 6.978,
#    'profile_path': '/jJ8UKek4GvQrQUP9q97Kq2MWVqi.jpg',
#    'character': 'Aníbal "Río" Cortés',
#    'credit_id': '5a4227c89251411f4f04a5b3',
#    'order': 6},
#   {'adult': False,
#    'gender': 1,
#    'id': 1972707,
#    'known_for_department': 'Acting',
#    'name': 'Esther Acebo',
#    'original_name': 'Esther Acebo',
#    'popularity': 7.786,
#    'profile_path': '/2v2eOKCjnQfY3jCsowtH8wLxFMC.jpg',
#    'character': 'Mónica "Estocolmo" Gaztambide',
#    'credit_id': '5a773f680e0a26598500132a',
#    'order': 7},
#   {'adult': False,
#    'gender': 2,
#    'id': 18478,
#    'known_for_department': 'Acting',
#    'name': 'Rodrigo de la Serna',
#    'original_name': 'Rodrigo de la Serna',
#    'popularity': 2.863,
#    'profile_path': '/vMuKUJSnEGOmjjLYzVDKGukiaCr.jpg',
#    'character': 'Martín "Palermo" Berrote',
#    'credit_id': '5d2e07af839d93000eefbc63',
#    'order': 8},
#   {'adult': False,
#    'gender': 2,
#    'id': 944099,
#    'known_for_department': 'Acting',
#    'name': 'Enrique Arce',
#    'original_name': 'Enrique Arce',
#    'popularity': 3.156,
#    'profile_path': '/1lACQepfukuZ0l6FnUpMO03WxcJ.jpg',
#    'character': 'Arturo Román',
#    'credit_id': '5a773eeac3a368227b001336',
#    'order': 9},
#   {'adult': False,
#    'gender': 2,
#    'id': 1898026,
#    'known_for_department': 'Acting',
#    'name': 'Darko Peric',
#    'original_name': 'Darko Peric',
#    'popularity': 2.704,
#    'profile_path': '/9IsIRW3PE105bfwen4IzGPXfmQc.jpg',
#    'character': 'Mirko "Helsinki" Dragic',
#    'credit_id': '5a773f9a92514177690011a6',
#    'order': 10},
#   {'adult': False,
#    'gender': 2,
#    'id': 1131415,
#    'known_for_department': 'Acting',
#    'name': 'Hovik Keuchkerian',
#    'original_name': 'Hovik Keuchkerian',
#    'popularity': 1.597,
#    'profile_path': '/o5cGKWHlZl4RFROYlT2hD95j0lN.jpg',
#    'character': 'Bogotá',
#    'credit_id': '5d2e078f6a300b000fa4d50c',
#    'order': 11},
#   {'adult': False,
#    'gender': 2,
#    'id': 1076809,
#    'known_for_department': 'Acting',
#    'name': 'Luka Peroš',
#    'original_name': 'Luka Peroš',
#    'popularity': 3.185,
#    'profile_path': '/lfh7959EpR9gAvrjObNGXaUg2qF.jpg',
#    'character': 'Jakov "Marsella"',
#    'credit_id': '610d419d323eba005dd9c933',
#    'order': 12},
#   {'adult': False,
#    'gender': 1,
#    'id': 1423493,
#    'known_for_department': 'Acting',
#    'name': 'Belén Cuesta',
#    'original_name': 'Belén Cuesta',
#    'popularity': 5.321,
#    'profile_path': '/xxaNCeIuLh7nZvuCrwANO3zwI5g.jpg',
#    'character': 'Julia "Manila"',
#    'credit_id': '610d41ae5a4690005ff40b54',
#    'order': 13},
#   {'adult': False,
#    'gender': 2,
#    'id': 51902,
#    'known_for_department': 'Acting',
#    'name': 'Fernando Cayo',
#    'original_name': 'Fernando Cayo',
#    'popularity': 2.058,
#    'profile_path': '/sglfXHNFlzOBBLuRrbDkxghSW4H.jpg',
#    'character': 'Luis Tamayo',
#    'credit_id': '610d41fa323eba005dd9c9d8',
#    'order': 14},
#   {'adult': False,
#    'gender': 1,
#    'id': 16442,
#    'known_for_department': 'Acting',
#    'name': 'Najwa Nimri',
#    'original_name': 'Najwa Nimri',
#    'popularity': 7.031,
#    'profile_path': '/hvLbKkDIT4FqSS8djmW5voNd0O4.jpg',
#    'character': 'Alicia Sierra',
#    'credit_id': '5d2e09e8caab6d1e81a3b6f2',
#    'order': 15},
#   {'adult': False,
#    'gender': 2,
#    'id': 1473729,
#    'known_for_department': 'Acting',
#    'name': 'Fernando Soto',
#    'original_name': 'Fernando Soto',
#    'popularity': 1.4,
#    'profile_path': '/9tqHD2lgTyEaINR6OBQHnPfGVT9.jpg',
#    'character': 'Angèl di Maria',
#    'credit_id': '618618ca5545ca0028ca057a',
#    'order': 500}],
#  'crew': [],
#  'id': 71446}

# %%
api_key = "e226f4a5f5bace766952aa0d17182959"
api_link = "https://api.themoviedb.org/3"
params = {'api_key':api_key}
header = {'Accept': 'application/json'}
response = requests.get(api_link + "/trending/tv/week", headers = header, params=params,verify=False)
ids= []
for i in response.json()['results'][:5]:
    ids.append(i.get("id"))
for id in ids:
    r2 = requests.get(api_link+"/tv/"+str(id),headers=header,params=param,verify=False)
    data = r2.json()
    if data.get("tagline") !="":
        print(data.get("tagline"))
    else:
        print("")
# Out:
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 45.6 billion won is child's play.
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Not everyone wants to be followed.
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# The perfect robbery.
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Hold on to your humanity.
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Change your fate.

# %%
param ={'api_key':'465eecab44c8ee8bb183fa7e2232c87b','query':'3 idiots'}
r = requests.get('https://api.themoviedb.org/3/search/movie',verify=False,params=param)
id = r.json()['results'][0]['id']

param ={'api_key':'465eecab44c8ee8bb183fa7e2232c87b'}
r = requests.get('https://api.themoviedb.org/3/movie/'+str(id),verify=False,params=param)
data = r.json()

print(r.url)
print(data['vote_count'],end=' ')
print(data['vote_average'])
data
# Out:
# https://api.themoviedb.org/3/movie/20453?api_key=465eecab44c8ee8bb183fa7e2232c87b
# 1709 8.0
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'adult': False,
#  'backdrop_path': '/6x00zPSgxcndnNvaFHdMtMT5Ytg.jpg',
#  'belongs_to_collection': None,
#  'budget': 9000000,
#  'genres': [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}],
#  'homepage': 'http://idiotsacademy.zapak.com/idiotsmain.php',
#  'id': 20453,
#  'imdb_id': 'tt1187043',
#  'original_language': 'hi',
#  'original_title': '3 Idiots',
#  'overview': 'In the tradition of “Ferris Bueller’s Day Off” comes this refreshing comedy about a rebellious prankster with a crafty mind and a heart of gold. Rascal. Joker. Dreamer. Genius... You\'ve never met a college student quite like "Rancho." From the moment he arrives at India\'s most prestigious university, Rancho\'s outlandish schemes turn the campus upside down—along with the lives of his two newfound best friends. Together, they make life miserable for "Virus," the school’s uptight and heartless dean. But when Rancho catches the eye of the dean\'s sexy daughter, Virus sets his sights on flunking out the "3 idiots" once and for all.',
#  'popularity': 61.44,
#  'poster_path': '/66A9MqXOyVFCssoloscw79z8Tew.jpg',
#  'production_companies': [{'id': 3781,
#    'logo_path': None,
#    'name': 'Vidhu Vinod Chopra Productions',
#    'origin_country': 'IN'},
#   {'id': 44164,
#    'logo_path': '/oZNzUp0YbfaKLaVTYghcnM4tYQv.png',
#    'name': 'Vinod Chopra Films',
#    'origin_country': 'IN'}],
#  'production_countries': [{'iso_3166_1': 'IN', 'name': 'India'}],
#  'release_date': '2009-12-23',
#  'revenue': 70000000,
#  'runtime': 170,
#  'spoken_languages': [{'english_name': 'Hindi',
#    'iso_639_1': 'hi',
#    'name': 'हिन्दी'},
#   {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}],
#  'status': 'Released',
#  'tagline': "Don't be Stupid. Be an I.D.I.O.T.",
#  'title': '3 Idiots',
#  'video': False,
#  'vote_average': 8.0,
#  'vote_count': 1709}

# %%
param ={'api_key':'465eecab44c8ee8bb183fa7e2232c87b','query':'Marvel Studios'}
r = requests.get('https://api.themoviedb.org/3/search/company',verify=False,params=param)
print(r.json()['results'][0]['id'])
# Out:
# 420
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
param ={'api_key':'465eecab44c8ee8bb183fa7e2232c87b','query':'Inception'}
r = requests.get('https://api.themoviedb.org/3/search/movie',verify=False,params=param)
data2 = r.json()
id = r.json()['results'][0]['id']

param ={'api_key':'465eecab44c8ee8bb183fa7e2232c87b'}
r = requests.get('https://api.themoviedb.org/3/movie/'+str(id)+'/similar',verify=False,params=param)
data = r.json()
for i in data['results'][:5]:
    print(i['title'],end=' ')
    print(i['popularity'])
for i in data2['results']:
    print(i)
# Out:
# The Giver 22.413
# Horrible Bosses 2 31.157
# Non-Stop 20.201
# Kingsman: The Secret Service 58.675
# The Art of the Steal 22.55
# {'adult': False, 'backdrop_path': '/s3TBrRGB1iav7gFOCNx3H31MoES.jpg', 'genre_ids': [28, 878, 12], 'id': 27205, 'original_language': 'en', 'original_title': 'Inception', 'overview': 'Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: "inception", the implantation of another person\'s idea into a target\'s subconscious.', 'popularity': 148.693, 'poster_path': '/9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg', 'release_date': '2010-07-15', 'title': 'Inception', 'video': False, 'vote_average': 8.3, 'vote_count': 30160}
# {'adult': False, 'backdrop_path': '/sABMpHRCmt7qg9q6AFbZ1jPU1Jf.jpg', 'genre_ids': [16, 28, 53, 878], 'id': 64956, 'original_language': 'en', 'original_title': 'Inception: The Cobol Job', 'overview': "The Cobol Job is a fourteen-minute animated prequel to Christopher Nolan’s award-winning movie: Inception, detailing the heist on Mr. Kaneda's mind by Nash, Cobb, Arthur, and several Cobol Engineering thugs.", 'popularity': 9.436, 'poster_path': '/sNxqwtyHMNQwKWoFYDqcYTui5Ok.jpg', 'release_date': '2010-12-07', 'title': 'Inception: The Cobol Job', 'video': False, 'vote_average': 7.3, 'vote_count': 267}
# {'adult': False, 'backdrop_path': None, 'genre_ids': [35], 'id': 542438, 'original_language': 'en', 'original_title': 'Bikini Inception', 'overview': "Two flunky Janitors in an Arctic Lab perform unauthorized experiments transporting them to a beach dream world in Malibu California w/50 beautiful young girls and a female Brazilian PhD Student wearing only a bra and panties. A '67 Muscle car races chases horses guns fights surfing, sumo wrestler, wolf monster, underwater scenes tons of gorgeous models. Sexy sci-fi fun.", 'popularity': 1.247, 'poster_path': '/mNASlEOFX2c9upxaSbgeKFvIr1L.jpg', 'release_date': '2015-05-19', 'title': 'Bikini Inception', 'video': False, 'vote_average': 7, 'vote_count': 1}
# {'adult': False, 'backdrop_path': None, 'genre_ids': [], 'id': 250845, 'original_language': 'en', 'original_title': 'WWA The Inception', 'overview': 'The first World Wrestling Allstars pay per view, live from Sydney, Australia! A tournament titled "7 Deadly Sins", each round having a stipulation match, the winner will be crowned the first ever WWA Heavyweight Champion! Wrestlers such as Jeff Jarrett, Road Dogg, Jerry Lawler all compete in the tournament, with the WWA Commissioner, Bret Hart not too far away to make sure nothing gets to far out of hand!', 'popularity': 1.12, 'poster_path': None, 'release_date': '2001-10-26', 'title': 'WWA The Inception', 'video': True, 'vote_average': 3.1, 'vote_count': 5}
# {'adult': False, 'backdrop_path': '/vYJRSrZmUcL7FPhOeCk3n6rFRRp.jpg', 'genre_ids': [18, 9648], 'id': 846190, 'original_language': 'fa', 'original_title': 'Aghaz', 'overview': 'Young man (Erfan) wants to do something important,It has a lot of risk for him But he must make a decision,Though everyone around them opposes doing so,The boy decides that...', 'popularity': 0.701, 'poster_path': '/jYxQqa3ZaXhhG89YEUZkxUfKFdm.jpg', 'release_date': '2014-02-12', 'title': 'Inception', 'video': False, 'vote_average': 10, 'vote_count': 2}
# {'adult': False, 'backdrop_path': None, 'genre_ids': [], 'id': 350632, 'original_language': 'en', 'original_title': 'Nātyārambham', 'overview': 'On certain Adavus: the basic steps in Bharatanatyam. The first part covers Tatta Adavu, Natta Adavu, Visharu Adavu , Tatti Metti Adavu and Teermanam Adavu.', 'popularity': 0.6, 'poster_path': None, 'title': 'The Inception of Dramatic Representation', 'video': True, 'vote_average': 5.8, 'vote_count': 3}
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
import requests

api_key = "e226f4a5f5bace766952aa0d17182959"
api_link = "https://api.themoviedb.org/3"
params = {'api_key':api_key,'language':'en-US'}
header = {'Accept': 'application/json'}
response = requests.get(api_link + "/genre/movie/list", headers = header, params=params,verify=False)
data = response.json()
d = {}
for i in data['genres']:
    d[i['id']] = i['name']

params = {'api_key':api_key,'region':'US','language':'en-US'}
header = {'Accept': 'application/json'}
response = requests.get(api_link + "/movie/top_rated", headers = header, params=params,verify=False)
data = response.json()

count = 0
for i in data['results']:
    if count==10:
        break
    if i['original_language'] == 'en':
        print(i['title'],end=' - ')
        c = 0
        for j in i['genre_ids']:
            if c==0:
                print(d[j],end='')
            else:
                print(", ",end='')
                print(d[j],end='')
            c+=1
        print("")
        count+=1
# Out:
# The Shawshank Redemption - Drama, Crime
# The Godfather - Drama, Crime
# Gabriel's Inferno Part II - Romance
# Gabriel's Inferno Part III - Romance, Comedy
# Gabriel's Inferno - Romance
# Schindler's List - Drama, History, War
# The Godfather: Part II - Drama, Crime
# Wolfwalkers - Animation, Family, Adventure, Fantasy
# The Green Mile - Fantasy, Drama, Crime
# 12 Angry Men - Drama
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
api_key = "e226f4a5f5bace766952aa0d17182959"
api_link = "https://api.themoviedb.org/3"
params = {'api_key':api_key,'language':'en-US'}
header = {'Accept': 'application/json'}
response = requests.get(api_link + "/genre/movie/list", headers = header, params=params,verify=False)
data = response.json()
d = {}
for i in data['genres']:
    d[i['id']] = i['name']
d
# Out:
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {28: 'Action',
#  12: 'Adventure',
#  16: 'Animation',
#  35: 'Comedy',
#  80: 'Crime',
#  99: 'Documentary',
#  18: 'Drama',
#  10751: 'Family',
#  14: 'Fantasy',
#  36: 'History',
#  27: 'Horror',
#  10402: 'Music',
#  9648: 'Mystery',
#  10749: 'Romance',
#  878: 'Science Fiction',
#  10770: 'TV Movie',
#  53: 'Thriller',
#  10752: 'War',
#  37: 'Western'}

# %%
api_key = "e226f4a5f5bace766952aa0d17182959"
api_link = "https://api.themoviedb.org/3"
params = {'api_key':api_key,'language':'en-US'}
header = {'Accept': 'application/json'}
response = requests.get(api_link + "/person/popular", headers = header, params=params,verify=False)
data = response.json()
id = data['results'][0]['id']
response = requests.get(api_link + "/person/"+str(id), headers = header, params=params,verify=False)
 
print(data['results'][0]['id'])
print(data['results'][0]['name'],end=' - ')
print(response.json()['place_of_birth'])
# Out:
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 229396
# Ruby O. Fee - San José, Costa Rica

# %%
api_key = "e226f4a5f5bace766952aa0d17182959"
api_link = "https://api.themoviedb.org/3"
params = {'api_key':api_key,'query':'Tom Cruise'}
header = {'Accept': 'application/json'}
response = requests.get(api_link + "/search/person", headers = header, params=params,verify=False)
id = response.json()['results'][0]['id']
response = requests.get(api_link + "/person/"+str(id)+"/movie_credits", headers = header, params=params,verify=False)
data = response.json()
films = ['Top Gun','Mission: Impossible - Fallout','Minority Report',
'Edge of Tomorrow']
d = {}
for i in data['cast']:
    if i['title'] in films:
        d[i['title']] = i['character']
for i in films:
    print(d[i])
# Out:
# Lt. Pete 'Maverick' Mitchell
# Ethan Hunt
# Chief John Anderton
# Cage
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
api_key = "e226f4a5f5bace766952aa0d17182959"
api_link = "https://api.themoviedb.org/3"
page_num = 1
for page_num in range(1,24):
    params = {'api_key':api_key,'page':page_num}
    header = {'Accept': 'application/json'}
    response = requests.get(api_link + "/tv/airing_today", headers = header, params=params,verify=False)
    for i in response.json()['results']:
        if i['original_language'] =='en':
            print(i['name'])
# Out:
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Rachael Ray
# The Price Is Right
# Wheel of Fortune
# Days of Our Lives
# Fear the Walking Dead
# The Simpsons
# 4400
# Jeopardy!
# The Rookie
# The Walking Dead: World Beyond
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# SEAL Team
# 9-1-1
# Family Guy
# NCIS
# Naked News
# Doctor Who
# NCIS: Los Angeles
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# PBS NewsHour
# Emmerdale
# The Boys
# Yellowstone
# NCIS: Hawai'i
# The Daily Show with Trevor Noah
# Richard Osman's House of Games
# Succession
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Bob's Burgers
# Heartland
# General Hospital
# The Ellen DeGeneres Show
# Curb Your Enthusiasm
# Let's Make a Deal
# Dexter: New Blood
# Hightown
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Coronation Street
# BMF
# Last Week Tonight with John Oliver
# The Tonight Show Starring Jimmy Fallon
# Maury
# All American
# The People's Court
# Insecure
# Murdoch Mysteries
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Divorce Court
# The Equalizer
# American Rust
# The Bold and the Beautiful
# PBS NewsHour Weekend
# People Puzzler
# Judge Jerry
# F1 Paddock Pass
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Angela Black
# Countryfile
# The Smurfs
# America's Funniest Home Videos
# The Real Housewives of Salt Lake City
# Pillow Talk
# WWE Raw
# The Real Housewives of Melbourne
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# On the Case with Paula Zahn
# EastEnders
# Judy Justice
# The Great North
# Celebrity Wheel of Fortune
# The Neighborhood
# Bob Hearts Abishola
# Dalgliesh
# The Notebook
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# The Outlaws
# Total Control
# The Voice
# Match of the Day 2
# The Larkins
# Wheeler Dealers
# Moonshiners Master Distiller
# 90 Day Fiancé: The Other Way
# The Circus
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# The Big Leap
# Escape to the Chateau
# Family Feud Canada
# Squidbillies
# Hoarders
# We're Here
# The Great Canadian Baking Show
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Intervention
# I Love a Mama's Boy
# The Osbournes Want to Believe
# Alaskan Bush People
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Being The Elite
# 999: On the Front Line
# Highway Thru Hell
# AEW Dark: Elevation
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# The Real Housewives of Potomac
# The Young and the Restless
# The Engineering That Built the World
# When Big Things Go Wrong
# អព្ភូតហេតុស្នេហ៍ ធីតាដើមស្រូវ
# obsessed with the scent of sandalwood
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Only Connect
# Hornby: A Model World
# Diana
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# wave of life
# Cinderella Slippers
# Sea of ​​Love
# Change love change planet
# Mr. Tawan's Evil Rose
# Frankie Boyle's New World Order
# The Rachel Maddow Show
# WWE Raw Talk
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# The Top Ten Revealed
# This Is Life with Lisa Ling
# The Family Chantel
# Home and Away
# Holiday Baking Championship
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Mastermind
# Joe Pera Talks With You
# Love Flower Crown
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Swan Wings
# Love Regiment
# Zindagi Ki Mehek
# Motorway Cops: Catching Britain's Speeders
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Wife's anger
# Love Eternal Chandra
# Wo Ai Ni Tur Tee Ruk
# Monster Boy Tricks
# Luang Kah Lah Ruk
# Prem Bandhan
# Boiling Sea
# MEKONG TREASURE
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Tug of Words
# Blade Runner: Black Lotus
# Below Deck
# Richard Hammond's Workshop
# Naked and Afraid of Love
# Outback Opal Hunters
# Showtrial
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# The Only Way Is Essex
# The Block
# Homestead Rescue
# Dr. Phil
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Best Shape of My Life
# Pizza Wars
# Big Brother VIP Australia
# Antiques Roadshow
# The Big Bake: Holiday
# Celebrity MasterChef Australia
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Murdertown
# Parental Guidance
# Renovation, Inc.
# Min Badi AlToufan

# %%
api_key = "e226f4a5f5bace766952aa0d17182959"
api_link = "https://api.themoviedb.org/3"
params = {'api_key':api_key,'query':'James McAvoy'}
header = {'Accept': 'application/json'}
response = requests.get(api_link + "/search/person", headers = header, params=params,verify=False)
id = response.json()['results'][0]['id']
response = requests.get(api_link + "/person/"+str(id)+"/movie_credits", headers = header, params=params,verify=False)
data = response.json()
films = ['Deadpool 2']
d = {}
found = False
for i in data['cast']:
    if i['title'] in films:
        found = True
if found == True:
    print("Yes")
else:
    print("No")
data
# Out:
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Yes
# {'cast': [{'original_title': 'Strings',
#    'poster_path': '/bCZu9u1Y54AOSKTl1hq1piS71US.jpg',
#    'video': False,
#    'overview': 'Strings is a mythological story about the son of a king, Hal Tara, who sets out on a journey to avenge the death of his father. To his surprise he discovers the truth of his own people - and where he least expects it - he finds true love.',
#    'release_date': '2004-10-24',
#    'vote_count': 53,
#    'adult': False,
#    'vote_average': 6.7,
#    'backdrop_path': '/d4qvST6E66quWX6VVHolT2ccabx.jpg',
#    'title': 'Strings',
#    'genre_ids': [12, 16, 18, 14],
#    'id': 21290,
#    'original_language': 'en',
#    'popularity': 4.849,
#    'character': 'Hal',
#    'credit_id': '52fe4413c3a368484e00e095',
#    'order': 0},
#   {'genre_ids': [18],
#    'original_language': 'en',
#    'original_title': "Inside I'm Dancing",
#    'poster_path': '/2umd8KCnjamgEk9RpSUDQ9TltbW.jpg',
#    'video': False,
#    'id': 31165,
#    'overview': "Michael is a 24-year-old who has cerebral palsy and long-term resident of the Carrigmore Residential Home for the Disabled, run by the formidable Eileen. His life is transformed when the maverick Rory O'Shea moves in.",
#    'release_date': '2004-10-15',
#    'vote_count': 149,
#    'vote_average': 7.4,
#    'adult': False,
#    'backdrop_path': '/jLhfSyEbQdlnCGWBOh6gQ3XpTgT.jpg',
#    'title': "Inside I'm Dancing",
#    'popularity': 7.769,
#    'character': "Rory O'Shea",
#    'credit_id': '52fe44659251416c9100f2c5',
#    'order': 0},
#   {'poster_path': '/rTvUr2ESdZ1Ht5zNbgUNmNEHyUT.jpg',
#    'video': False,
#    'vote_average': 6.5,
#    'overview': 'Doormat Wesley Gibson discovers that his recently murdered father - who Wesley never knew - belonged to a secret guild of assassins. After a leather-clad sexpot drafts Wesley into the society, he hones his innate killing skills and turns avenger.',
#    'release_date': '2008-06-19',
#    'vote_count': 5713,
#    'adult': False,
#    'backdrop_path': '/qqhzXiNyCotzJdyEbi41EtzYYYI.jpg',
#    'title': 'Wanted',
#    'genre_ids': [28, 53, 80],
#    'id': 8909,
#    'original_language': 'en',
#    'original_title': 'Wanted',
#    'popularity': 25.227,
#    'character': 'Wesley Gibson',
#    'credit_id': '52fe44c7c3a36847f80a9771',
#    'order': 0},
#   {'original_language': 'en',
#    'original_title': 'Starter for 10',
#    'poster_path': '/wUT0OLYY9HouuAkVFNchponJ5gQ.jpg',
#    'video': False,
#    'vote_average': 6.5,
#    'overview': 'In 1985, against the backdrop of Thatcherism, Brian Jackson enrolls in the University of Bristol, a scholarship boy from seaside Essex with a love of knowledge for its own sake and a childhood spent watching University Challenge, a college quiz show. At Bristol he tries out for the Challenge team and falls under the spell of Alice, a lovely blond with an extensive sexual past.',
#    'release_date': '2006-09-13',
#    'vote_count': 294,
#    'title': 'Starter for 10',
#    'adult': False,
#    'backdrop_path': '/1aIM2oiOBH5TJsvjcdU6ca9zwQX.jpg',
#    'id': 14055,
#    'genre_ids': [18, 35, 10749],
#    'popularity': 9.037,
#    'character': 'Brian Jackson',
#    'credit_id': '52fe45c79251416c75062353',
#    'order': 0},
#   {'adult': False,
#    'backdrop_path': '/i4YjA78Tf60YW5tfBJmW8Q8X1QU.jpg',
#    'genre_ids': [80, 18, 36],
#    'id': 60309,
#    'original_language': 'en',
#    'original_title': 'The Conspirator',
#    'overview': 'Mary Surratt is the lone female charged as a co-conspirator in the assassination trial of Abraham Lincoln. As the whole nation turns against her, she is forced to rely on her reluctant lawyer to uncover the truth and save her life.',
#    'poster_path': '/7oF9c8F9PfswtMAuodi6gMEttuo.jpg',
#    'release_date': '2010-09-10',
#    'title': 'The Conspirator',
#    'video': False,
#    'vote_average': 6.6,
#    'vote_count': 340,
#    'popularity': 7.462,
#    'character': 'Frederick Aiken',
#    'credit_id': '52fe461fc3a368484e080183',
#    'order': 0},
#   {'original_language': 'en',
#    'original_title': 'Gnomeo & Juliet',
#    'poster_path': '/vVQwgfS9gSFviVT4gS7tZAmhRFc.jpg',
#    'title': 'Gnomeo & Juliet',
#    'vote_average': 5.8,
#    'id': 45772,
#    'overview': "A version of Shakespeare's play, set in the world of warring indoor and outdoor gnomes. Garden gnomes Gnomeo and Juliet have as many obstacles to overcome as their quasi namesakes when they are caught up in a feud between neighbors. But with plastic pink flamingos and lawnmower races in the mix, can this young couple find lasting happiness?",
#    'release_date': '2011-01-13',
#    'adult': False,
#    'backdrop_path': '/w3LLngJIAA1R7Mp2S3G0HZl2R3H.jpg',
#    'vote_count': 1571,
#    'genre_ids': [16, 10751],
#    'video': False,
#    'popularity': 41.153,
#    'character': 'Gnomeo (voice)',
#    'credit_id': '52fe46d2c3a36847f8114209',
#    'order': 0},
#   {'adult': False,
#    'backdrop_path': '/24TPn8sFUXZXkTnkWdJ06wyhit8.jpg',
#    'genre_ids': [53, 80, 18, 9648],
#    'id': 68727,
#    'original_language': 'en',
#    'original_title': 'Trance',
#    'overview': 'A violent gang enlists the help of a hypnotherapist in an attempt to locate a painting which somehow vanished in the middle of a heist.',
#    'poster_path': '/3MVYuyVknNA9yC0Gy6z3zDAiWfX.jpg',
#    'release_date': '2013-03-27',
#    'title': 'Trance',
#    'video': False,
#    'vote_average': 6.6,
#    'vote_count': 1763,
#    'popularity': 16.726,
#    'character': 'Simon',
#    'credit_id': '52fe47a1c3a368484e0d18f7',
#    'order': 0},
#   {'genre_ids': [18, 16, 10751, 35],
#    'id': 51052,
#    'original_language': 'en',
#    'original_title': 'Arthur Christmas',
#    'poster_path': '/sPCrGLdTMn0ud3oAJG37VDxpQfZ.jpg',
#    'video': False,
#    'vote_average': 6.7,
#    'title': 'Arthur Christmas',
#    'overview': 'Each Christmas, Santa and his vast army of highly trained elves produce gifts and distribute them around the world in one night. However, when one of 600 million children to receive a gift from Santa on Christmas Eve is missed, it is deemed ‘acceptable’ to all but one—Arthur. Arthur Claus is Santa’s misfit son who executes an unauthorised rookie mission to get the last present half way around the globe before dawn on Christmas morning.',
#    'release_date': '2011-11-10',
#    'adult': False,
#    'backdrop_path': '/t4WQ36MAZf1sgiPKocTa0KBGBKI.jpg',
#    'vote_count': 1046,
#    'popularity': 30.836,
#    'character': 'Arthur (voice)',
#    'credit_id': '52fe47dfc3a36847f814ce2d',
#    'order': 0},
#   {'adult': False,
#    'backdrop_path': '/btgHGn0YZt5Xq2ltoMrbluTm2Pf.jpg',
#    'genre_ids': [28, 12, 80],
#    'id': 93828,
#    'original_language': 'en',
#    'original_title': 'Welcome to the Punch',
#    'overview': "When notorious criminal Jacob Sternwood is forced to return to London, it gives detective Max Lewinsky one last chance to take down the man he's always been after.",
#    'poster_path': '/6mCyfp7nk1sTZNtvLSVGrO0sPeH.jpg',
#    'release_date': '2013-03-15',
#    'title': 'Welcome to the Punch',
#    'video': False,
#    'vote_average': 5.9,
#    'vote_count': 506,
#    'popularity': 8.287,
#    'character': 'Max Lewinsky',
#    'credit_id': '52fe49409251416c750c1fc7',
#    'order': 0},
#   {'overview': 'A bigoted junkie cop suffering from bipolar disorder and drug addiction manipulates and hallucinates his way through the festive season in a bid to secure promotion and win back his wife and daughter.',
#    'release_date': '2013-09-23',
#    'adult': False,
#    'backdrop_path': '/wpl0kQvawRlaH7l68SoIAAyOmgV.jpg',
#    'genre_ids': [80, 18, 35],
#    'vote_count': 1315,
#    'original_language': 'en',
#    'id': 85889,
#    'poster_path': '/opejdaSr1Fl6JoCMmuu2LpKvpdR.jpg',
#    'title': 'Filth',
#    'video': False,
#    'vote_average': 6.9,
#    'original_title': 'Filth',
#    'popularity': 11.579,
#    'character': 'Bruce Robertson',
#    'credit_id': '52fe49649251416c910abe03',
#    'order': 0},
#   {'video': False,
#    'vote_average': 5.9,
#    'overview': 'Eccentric scientist Victor Von Frankenstein creates a grotesque creature in an unorthodox scientific experiment.',
#    'release_date': '2015-11-10',
#    'vote_count': 1692,
#    'adult': False,
#    'backdrop_path': '/8kJNwEkHIg4NePpFbYFwR8NC4UM.jpg',
#    'title': 'Victor Frankenstein',
#    'genre_ids': [18, 878, 53],
#    'id': 228066,
#    'original_language': 'en',
#    'original_title': 'Victor Frankenstein',
#    'poster_path': '/iIF0y5Gq0XxRgddaWtVTqqHboWp.jpg',
#    'popularity': 29.017,
#    'character': 'Victor Von Frankenstein',
#    'credit_id': '52fe4ebe9251416c75160cd1',
#    'order': 0},
#   {'poster_path': '/wCxiOB5dgShUrsUkyTaMsRTiw7j.jpg',
#    'video': False,
#    'vote_average': 6.7,
#    'overview': 'Told from the male perspective, the story of a couple trying to reclaim the life and love they once knew and pick up the pieces of a past that may be too far gone.',
#    'release_date': '2014-10-10',
#    'vote_count': 178,
#    'adult': False,
#    'backdrop_path': '/ucSAipPMsiDeXoTp0OQj3cf953g.jpg',
#    'title': 'The Disappearance of Eleanor Rigby: Him',
#    'genre_ids': [10749, 18],
#    'id': 276401,
#    'original_language': 'en',
#    'original_title': 'The Disappearance of Eleanor Rigby: Him',
#    'popularity': 8.569,
#    'character': 'Conor',
#    'credit_id': '539a24480e0a26363b00027b',
#    'order': 0},
#   {'video': False,
#    'vote_average': 6.5,
#    'overview': "After the re-emergence of the world's first mutant, world-destroyer Apocalypse, the X-Men must unite to defeat his extinction level plan.",
#    'release_date': '2016-05-18',
#    'vote_count': 10816,
#    'adult': False,
#    'backdrop_path': '/pCssRYbILVduCYDgrcRG0T8W4FN.jpg',
#    'title': 'X-Men: Apocalypse',
#    'genre_ids': [28, 12, 878, 14],
#    'id': 246655,
#    'original_language': 'en',
#    'original_title': 'X-Men: Apocalypse',
#    'poster_path': '/2mtQwJKVKQrZgTz49Dizb25eOQQ.jpg',
#    'popularity': 81.787,
#    'character': 'Charles Xavier / Professor X',
#    'credit_id': '541f8b8b0e0a26179a001025',
#    'order': 0},
#   {'genre_ids': [18, 53, 10749],
#    'title': 'Submergence',
#    'original_language': 'en',
#    'original_title': 'Submergence',
#    'poster_path': '/sPwANB5cMjJLfRru45sc7Mnkjrq.jpg',
#    'video': False,
#    'vote_average': 5.4,
#    'id': 375327,
#    'release_date': '2017-09-22',
#    'vote_count': 221,
#    'adult': False,
#    'backdrop_path': '/dKfy1fUFinKcO0FmkRnAtZhM6DC.jpg',
#    'overview': 'While James More is held captive by terrorists in Somalia, thousands of miles away on the Greenland Sea, his lover Danny Flinders prepares to dive herself in a submersible into the deep bottom of the ocean, tormented by the memories of their brief encounter in France and her inability to know his whereabouts.',
#    'popularity': 10.469,
#    'character': 'James More',
#    'credit_id': '56f86f0892514123cb000f6a',
#    'order': 0},
#   {'video': False,
#    'vote_average': 7.3,
#    'overview': 'Before Charles Xavier and Erik Lensherr took the names Professor X and Magneto, they were two young men discovering their powers for the first time. Before they were arch-enemies, they were closest of friends, working together with other mutants (some familiar, some new), to stop the greatest threat the world has ever known.',
#    'release_date': '2011-06-01',
#    'vote_count': 10573,
#    'adult': False,
#    'backdrop_path': '/7kURId6slyHNujYpCFm0Z1M3kRt.jpg',
#    'title': 'X-Men: First Class',
#    'genre_ids': [28, 878, 12],
#    'id': 49538,
#    'original_language': 'en',
#    'original_title': 'X-Men: First Class',
#    'poster_path': '/vUvlOY575rztBuJV3a0dbHW5MQR.jpg',
#    'popularity': 4.714,
#    'character': 'Charles Xavier (24 Years) / Professor X',
#    'credit_id': '52fe479bc3a36847f813ecbb',
#    'order': 0},
#   {'original_language': 'en',
#    'original_title': 'Split',
#    'poster_path': '/bqb9WsmZmDIKxqYmBJ9lj7J6hzn.jpg',
#    'video': False,
#    'vote_average': 7.3,
#    'overview': 'Though Kevin has evidenced 23 personalities to his trusted psychiatrist, Dr. Fletcher, there remains one still submerged who is set to materialize and dominate all the others. Compelled to abduct three teenage girls led by the willful, observant Casey, Kevin reaches a war for survival among all of those contained within him — as well as everyone around him — as the walls between his compartments shatter apart.',
#    'release_date': '2016-11-15',
#    'vote_count': 14371,
#    'adult': False,
#    'backdrop_path': '/9pkZesKMnblFfKxEhQx45YQ2kIe.jpg',
#    'title': 'Split',
#    'genre_ids': [27, 53],
#    'id': 381288,
#    'popularity': 70.673,
#    'character': 'Kevin Wendell Crumb',
#    'credit_id': '56b4094192514114eb003384',
#    'order': 0},
#   {'id': 450465,
#    'backdrop_path': '/ngBFDOsx13sFXiMweDoL54XYknR.jpg',
#    'adult': False,
#    'genre_ids': [53, 18, 878],
#    'overview': 'In a series of escalating encounters, former security guard David Dunn uses his supernatural abilities to track Kevin Wendell Crumb, a disturbed man who has twenty-four personalities. Meanwhile, the shadowy presence of Elijah Price emerges as an orchestrator who holds secrets critical to both men.',
#    'original_language': 'en',
#    'original_title': 'Glass',
#    'poster_path': '/svIDTNUoajS8dLEo7EosxvyAsgJ.jpg',
#    'title': 'Glass',
#    'video': False,
#    'vote_average': 6.7,
#    'release_date': '2019-01-16',
#    'vote_count': 6587,
#    'popularity': 68.113,
#    'character': 'Patricia / Dennis / Hedwig / The Beast / Barry / Heinrich / Jade / Ian / Mary Reynolds / Norma / Jalin / Kat / B.T. / Kevin Wendell Crumb / Mr. Pritchard / Felida / Luke / Goddard / Samuel / Polly',
#    'credit_id': '5900cbdbc3a3680fcc00de6d',
#    'order': 0},
#   {'title': 'My Son',
#    'adult': False,
#    'backdrop_path': '/wC3YxnkF5MvwXXstQF22zLVatYp.jpg',
#    'genre_ids': [80, 18, 9648],
#    'original_language': 'en',
#    'original_title': 'My Son',
#    'poster_path': '/8d4q6bf1PS6OX6F3syWnfBzFZg9.jpg',
#    'vote_count': 33,
#    'video': False,
#    'vote_average': 6.5,
#    'id': 750253,
#    'overview': "When a man's only son goes missing, he travels to the town where his ex-wife lives in search of answers. To play a man whose life is clouded by mystery, McAvoy will not be given a script of dialogue.",
#    'release_date': '2021-10-14',
#    'popularity': 28.355,
#    'character': 'Edmond Murray',
#    'credit_id': '5f7bc6ae9a64350039ba2b3c',
#    'order': 0},
#   {'vote_average': 7.5,
#    'overview': "Young Scottish doctor, Nicholas Garrigan decides it's time for an adventure after he finishes his formal education, so he decides to try his luck in Uganda, and arrives during the downfall of President Obote. General Idi Amin comes to power and asks Garrigan to become his personal doctor.",
#    'release_date': '2006-01-12',
#    'adult': False,
#    'backdrop_path': '/x75IDQL2N7pdCbfKjT5oGP8mBU5.jpg',
#    'vote_count': 1551,
#    'genre_ids': [18],
#    'id': 1523,
#    'original_language': 'en',
#    'original_title': 'The Last King of Scotland',
#    'poster_path': '/quckyadj0bYCzIXMDIi4lrwJfth.jpg',
#    'title': 'The Last King of Scotland',
#    'video': False,
#    'popularity': 20.49,
#    'character': 'Dr. Nicholas Garrigan',
#    'credit_id': '52fe42fac3a36847f803157b',
#    'order': 1},
#   {'overview': 'A biographical portrait of a pre-fame Jane Austen and her romance with a young Irishman.',
#    'release_date': '2007-03-02',
#    'adult': False,
#    'backdrop_path': '/yEr7nMRFB4rv5UGOLk6SxvHYE4A.jpg',
#    'vote_count': 922,
#    'genre_ids': [10749, 18],
#    'title': 'Becoming Jane',
#    'original_language': 'en',
#    'original_title': 'Becoming Jane',
#    'poster_path': '/yHA6JEn57MBGp2yGFgYyopJvk2O.jpg',
#    'video': False,
#    'id': 2977,
#    'vote_average': 7.3,
#    'popularity': 12.782,
#    'character': 'Tom Lefroy',
#    'credit_id': '52fe4378c3a36847f80569a3',
#    'order': 1},
#   {'adult': False,
#    'backdrop_path': '/3WcllQqwppGenyvk60hgIStvL34.jpg',
#    'genre_ids': [18, 10749],
#    'id': 4347,
#    'original_language': 'en',
#    'original_title': 'Atonement',
#    'overview': "As a 13-year-old, fledgling writer Briony Tallis irrevocably changes the course of several lives when she accuses her older sister's lover of a crime he did not commit.",
#    'poster_path': '/hMRIyBjPzxaSXWM06se3OcNjIQa.jpg',
#    'release_date': '2007-09-07',
#    'title': 'Atonement',
#    'video': False,
#    'vote_average': 7.7,
#    'vote_count': 3137,
#    'popularity': 17.933,
#    'character': 'Robbie Turner',
#    'credit_id': '52fe43bbc3a36847f806b5b5',
#    'order': 1},
#   {'adult': False,
#    'backdrop_path': '/e2XIc8YlZ2Ife5d9XOsR9BKgvVe.jpg',
#    'genre_ids': [14, 35, 10749],
#    'id': 7985,
#    'original_language': 'en',
#    'original_title': 'Penelope',
#    'overview': "Forlorn heiress Penelope Wilhern is cursed, and the only way out is to fall in love with someone of suitable stock. But how can she find her soul mate when she's sequestered inside her family's estate with only her parents to keep her company. This untraditional fairy tale about a girl who bucks convention to create her own happy ending.",
#    'poster_path': '/yq89qoyPEqugnTbIntLMCHRCupB.jpg',
#    'release_date': '2006-03-01',
#    'title': 'Penelope',
#    'video': False,
#    'vote_average': 6.7,
#    'vote_count': 1169,
#    'popularity': 13.131,
#    'character': 'Johnny/Max',
#    'credit_id': '52fe448bc3a36847f809c12d',
#    'order': 1},
#   {'genre_ids': [18, 10402, 10749],
#    'title': 'Bollywood Queen',
#    'original_language': 'en',
#    'original_title': 'Bollywood Queen',
#    'poster_path': '/2cAs19KiQp3UFeVRhCPObX2Y0wC.jpg',
#    'video': False,
#    'vote_average': 6.0,
#    'overview': "A cross cultural romance set in London's East End about a young girl of Indian heritage.",
#    'release_date': '2002-01-01',
#    'vote_count': 6,
#    'id': 44367,
#    'adult': False,
#    'backdrop_path': None,
#    'popularity': 2.353,
#    'character': 'Jay',
#    'credit_id': '52fe4685c3a36847f810399d',
#    'order': 1},
#   {'adult': False,
#    'backdrop_path': '/5p58QwB13mYjIJ9fJmT36ZZWWnu.jpg',
#    'genre_ids': [18],
#    'id': 157829,
#    'original_language': 'en',
#    'original_title': 'The Disappearance of Eleanor Rigby: Them',
#    'overview': "A New York couple's relationship is tested after the loss of their child. This film is the wide-released combination of the original two :him and :her volumes that premiered at the Cannes Film Festival.",
#    'poster_path': '/rFBfW5RJbjgOYufLvu2DP4A71JW.jpg',
#    'release_date': '2014-05-14',
#    'title': 'The Disappearance of Eleanor Rigby: Them',
#    'video': False,
#    'vote_average': 6.2,
#    'vote_count': 233,
#    'popularity': 9.599,
#    'character': 'Conor Ludlow',
#    'credit_id': '52fe4bd39251416c910e6ee1',
#    'order': 1},
#   {'id': 341013,
#    'adult': False,
#    'backdrop_path': '/g3hni0i9iAQ13jDGOFWavJFlojc.jpg',
#    'genre_ids': [28, 53],
#    'original_language': 'en',
#    'original_title': 'Atomic Blonde',
#    'poster_path': '/kV9R5h0Yct1kR8Hf8sJ1nX0Vz4x.jpg',
#    'vote_count': 5167,
#    'video': False,
#    'vote_average': 6.4,
#    'title': 'Atomic Blonde',
#    'overview': 'An undercover MI6 agent is sent to Berlin during the Cold War to investigate the murder of a fellow agent and recover a missing list of double agents.',
#    'release_date': '2017-07-26',
#    'popularity': 25.849,
#    'character': 'David Percival',
#    'credit_id': '56f4a475c3a368274e000c5d',
#    'order': 1},
#   {'release_date': '2014-05-15',
#    'adult': False,
#    'backdrop_path': '/hUPgIibqZlwbhs4N08cPzzc4f5K.jpg',
#    'genre_ids': [28, 12, 14, 878],
#    'vote_count': 12853,
#    'original_language': 'en',
#    'id': 127585,
#    'poster_path': '/9aq2sHfkkAFwH0wi4bZasXA8NbS.jpg',
#    'title': 'X-Men: Days of Future Past',
#    'video': False,
#    'vote_average': 7.5,
#    'original_title': 'X-Men: Days of Future Past',
#    'overview': 'The ultimate X-Men ensemble fights a war for the survival of the species across two time periods as they join forces with their younger selves in an epic battle that must change the past – to save our future.',
#    'popularity': 64.581,
#    'character': 'Charles Xavier / Professor X (Young)',
#    'credit_id': '52fe4affc3a368484e171fff',
#    'order': 1},
#   {'adult': False,
#    'backdrop_path': '/6H0CfLRcgq0Pcq34wNypC2V3W41.jpg',
#    'title': 'Dark Phoenix',
#    'genre_ids': [878, 28, 12],
#    'original_language': 'en',
#    'original_title': 'Dark Phoenix',
#    'poster_path': '/kZv92eTc0Gg3mKxqjjDAM73z9cy.jpg',
#    'id': 320288,
#    'video': False,
#    'vote_average': 6.0,
#    'overview': "The X-Men face their most formidable and powerful foe when one of their own, Jean Grey, starts to spiral out of control. During a rescue mission in outer space, Jean is nearly killed when she's hit by a mysterious cosmic force. Once she returns home, this force not only makes her infinitely more powerful, but far more unstable. The X-Men must now band together to save her soul and battle aliens that want to use Grey's new abilities to rule the galaxy.",
#    'release_date': '2019-06-05',
#    'vote_count': 4864,
#    'popularity': 52.385,
#    'character': 'Charles Xavier / Professor X',
#    'credit_id': '589f3c2e925141172101014a',
#    'order': 1},
#   {'adult': False,
#    'backdrop_path': '/8moTOzunF7p40oR5XhlDvJckOSW.jpg',
#    'id': 474350,
#    'genre_ids': [27, 14],
#    'original_language': 'en',
#    'original_title': 'It Chapter Two',
#    'poster_path': '/zfE0R94v1E8cuKAerbskfD3VfUt.jpg',
#    'video': False,
#    'vote_average': 6.9,
#    'vote_count': 6410,
#    'overview': "27 years after overcoming the malevolent supernatural entity Pennywise, the former members of the Losers' Club, who have grown up and moved away from Derry, are brought back together by a devastating phone call.",
#    'release_date': '2019-09-04',
#    'title': 'It Chapter Two',
#    'popularity': 202.461,
#    'character': 'Bill Denbrough',
#    'credit_id': '5acfcb829251417b72001543',
#    'order': 1},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [80, 18],
#    'id': 591293,
#    'original_language': 'en',
#    'original_title': 'Macbeth',
#    'overview': 'A chef and his restaurant-hostess wife resort to murder to take ownership of a high-class Glaswegian restaurant.',
#    'poster_path': '/cgHsEViwdHlPVIZWyd7ApHLbtWZ.jpg',
#    'release_date': '2005-11-14',
#    'title': 'Macbeth',
#    'video': False,
#    'vote_average': 8.3,
#    'vote_count': 3,
#    'popularity': 2.217,
#    'character': 'Joe Macbeth',
#    'credit_id': '5c9c119a9251410a5209f5fe',
#    'order': 1},
#   {'adult': False,
#    'backdrop_path': '/sM0AFy8yaQ7WbCPCUP8rifRabgd.jpg',
#    'genre_ids': [18, 10749],
#    'id': 665149,
#    'original_language': 'en',
#    'original_title': 'National Theatre Live: Cyrano de Bergerac',
#    'overview': 'Fierce with a pen and notorious in combat, Cyrano almost has it all - if only he could win the heart of his true love Roxane. There’s just one big problem: he has a nose as huge as his heart. Will a society engulfed by narcissism get the better of Cyrano - or can his mastery of language set Roxane’s world alight?',
#    'poster_path': '/oGBcO9o8i0PVLCCdTnWVCI34b0m.jpg',
#    'release_date': '2020-02-20',
#    'title': 'National Theatre Live: Cyrano de Bergerac',
#    'video': True,
#    'vote_average': 8.3,
#    'vote_count': 2,
#    'popularity': 3.319,
#    'character': 'Cyrano de Bergerac',
#    'credit_id': '5e246585bfeb8b0015d41b68',
#    'order': 1},
#   {'genre_ids': [99, 18, 53],
#    'original_language': 'en',
#    'original_title': "The Making of 'Split'",
#    'poster_path': '/u5B29EdugGRKgvbUsS5oUsjodfE.jpg',
#    'video': False,
#    'vote_average': 7.0,
#    'overview': "A piece in which Shyamalan discusses his growth as a person and a filmmaker, how the film reflects his growth, casting, script secrecy, characters, the film's style, influences (namely It Follows), locations and set design, and budget.",
#    'id': 685564,
#    'vote_count': 4,
#    'title': "The Making of 'Split'",
#    'adult': False,
#    'backdrop_path': None,
#    'release_date': '2017-04-18',
#    'popularity': 0.72,
#    'character': 'Himself',
#    'credit_id': '5e77ccdab1f68d0017e68512',
#    'order': 1},
#   {'id': 837548,
#    'adult': False,
#    'backdrop_path': '/g2xbutVPtv65Y5izhOrDqTkkNyq.jpg',
#    'genre_ids': [18, 35],
#    'original_language': 'en',
#    'original_title': 'Together',
#    'poster_path': '/oeocQg0Bhmy0pqqRy50wEo0iwFB.jpg',
#    'vote_count': 19,
#    'video': False,
#    'title': 'Together',
#    'vote_average': 6.9,
#    'overview': 'A husband and wife are forced to re-evaluate themselves and their relationship through the reality of the Covid-19 lockdown.',
#    'release_date': '2021-08-27',
#    'popularity': 5.059,
#    'character': 'He',
#    'credit_id': '60bd2d2171458f0029fdbf6c',
#    'order': 1},
#   {'release_date': '2001-10-04',
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [53, 27],
#    'vote_count': 69,
#    'original_language': 'en',
#    'original_title': 'Swimming Pool',
#    'poster_path': '/rHIvVrrfEtbVDoPxYJxwYQUKMeY.jpg',
#    'title': 'The Pool',
#    'video': False,
#    'vote_average': 5.1,
#    'id': 11376,
#    'overview': "School's out, exams are over, and it's time for real life to begin. But before 12 friends from the International High School in Prague disappear to the four corners of the earth, they intend to throw the best party of their lives. The idea to stage the party in Prague's biggest swimming pool is illegal but cool. And when Gregor, the laid-back leader of the group thinks an idea is good, then no-one else from the group objects. But what begins as the night of all nights quickly turns into a life and death struggle, as the friends come to realise that death itself is on the guest list... A mysterious masked killer sets a hunt in motion that ranges through the facility's halls and corridors. As the kids panic it begins to dawn on them that the killer must be one of them...",
#    'popularity': 4.778,
#    'character': 'Mike',
#    'credit_id': '52fe44349251416c7502c675',
#    'order': 2},
#   {'overview': "A historical drama that illustrates Russian author Leo Tolstoy's struggle to balance fame and wealth with his commitment to a life devoid of material things. The Countess Sofya, wife and muse to Leo Tolstoy, uses every trick of seduction on her husband's loyal disciple, whom she believes was the person responsible for Tolstoy signing a new will that leaves his work and property to the Russian people.",
#    'release_date': '2009-09-04',
#    'adult': False,
#    'backdrop_path': '/6ab5nkZ14mAVTxC0EszMXF3psEm.jpg',
#    'genre_ids': [18, 10749],
#    'vote_count': 149,
#    'original_language': 'en',
#    'original_title': 'The Last Station',
#    'poster_path': '/55cRqlB9X6qw9akovbdu8vrsDir.jpg',
#    'video': False,
#    'id': 36811,
#    'vote_average': 6.4,
#    'title': 'The Last Station',
#    'popularity': 7.916,
#    'character': 'Valentin Bulgakov',
#    'credit_id': '52fe460d9251416c91047761',
#    'order': 2},
#   {'overview': 'Told from the female perspective, the story of a couple trying to reclaim the life and love they once knew and pick up the pieces of a past that may be too far gone.',
#    'release_date': '2014-10-10',
#    'adult': False,
#    'backdrop_path': '/zWjcyGONx6RayBlOmDMOkXIrsuT.jpg',
#    'genre_ids': [18, 10749],
#    'vote_count': 170,
#    'original_language': 'en',
#    'original_title': 'The Disappearance of Eleanor Rigby: Her',
#    'poster_path': '/ynQT7JLYoLwV8P2ropoQEpTH7gG.jpg',
#    'id': 275060,
#    'video': False,
#    'vote_average': 6.8,
#    'title': 'The Disappearance of Eleanor Rigby: Her',
#    'popularity': 8.552,
#    'character': 'Conor',
#    'credit_id': '53950d890e0a266db70055f3',
#    'order': 2},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [],
#    'id': 881050,
#    'original_language': 'en',
#    'original_title': 'The Sands Between',
#    'overview': 'A woman has a phone conversation with her significant other which slowly deteriorates as she comes to realize that the world around her might not be real.',
#    'poster_path': '/9S3qvJTN1ereQi69anQ5TMDjFv2.jpg',
#    'release_date': '2021-09-25',
#    'title': 'The Sands Between',
#    'video': False,
#    'vote_average': 0.0,
#    'vote_count': 0,
#    'popularity': 1.209,
#    'character': 'Man',
#    'credit_id': '615ada57c8a2d4006230ac33',
#    'order': 2},
#   {'adult': False,
#    'backdrop_path': '/eXIkP7m7Eo5G5oN4RavL3PpGmeH.jpg',
#    'genre_ids': [35, 10749],
#    'id': 11823,
#    'original_language': 'en',
#    'original_title': 'Wimbledon',
#    'overview': 'British tennis player Peter clutches to an embarrassingly low position on the tennis-ranking ladder. Handed a wild card for Wimbledon, he expects it to be his final bow.',
#    'poster_path': '/nwFbj6gXVhbf0vCvCyVUUlD5AdB.jpg',
#    'release_date': '2004-09-13',
#    'title': 'Wimbledon',
#    'video': False,
#    'vote_average': 6.2,
#    'vote_count': 763,
#    'popularity': 9.328,
#    'character': 'Carl Colt',
#    'credit_id': '52fe448c9251416c75038b07',
#    'order': 3},
#   {'overview': 'Garden gnomes, Gnomeo & Juliet, recruit renown detective, Sherlock Gnomes, to investigate the mysterious disappearance of other garden ornaments.',
#    'release_date': '2018-03-15',
#    'adult': False,
#    'backdrop_path': '/jVUR1W6cq8VuT4A6N4fd2yDNhji.jpg',
#    'genre_ids': [16, 10751, 14, 35, 12, 9648],
#    'vote_count': 558,
#    'original_language': 'en',
#    'original_title': 'Sherlock Gnomes',
#    'poster_path': '/wqnzpJR3PwS4doVkAkt9seSEpoX.jpg',
#    'video': False,
#    'id': 370567,
#    'vote_average': 5.6,
#    'title': 'Sherlock Gnomes',
#    'popularity': 17.204,
#    'character': 'Gnomeo (voice)',
#    'credit_id': '565c2ad2c3a368506d007c11',
#    'order': 3},
#   {'vote_average': 6.4,
#    'overview': 'In the 1930s, a social set known to the press – who follow their every move – as the “Bright Young Things” are Adam and his friends who are eccentric, wild and entirely shocking to the older generation. Amidst the madness, Adam, who is well connected but totally broke, is desperately trying to get enough money to marry the beautiful Nina. While his attempts to raise cash are constantly thwarted, their friends seem to self-destruct, one-by-one, in an endless search for newer and faster sensations. Finally, when world events out of their control come crashing around them, they are forced to reassess their lives and what they value most.',
#    'release_date': '2003-05-16',
#    'adult': False,
#    'backdrop_path': '/gP3fRkvy0ABEorenM76QHKefBOa.jpg',
#    'vote_count': 58,
#    'genre_ids': [35],
#    'id': 15271,
#    'original_language': 'en',
#    'original_title': 'Bright Young Things',
#    'poster_path': '/m7ik01FJKBSEoy0L0PKz7eEf9kI.jpg',
#    'title': 'Bright Young Things',
#    'video': False,
#    'popularity': 5.764,
#    'character': 'Simon Balcairn',
#    'credit_id': '52fe46499251416c750738a7',
#    'order': 4},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [18],
#    'id': 270183,
#    'original_language': 'en',
#    'original_title': 'White Teeth',
#    'overview': "An adaptation of Zadie Smith's bestseller concerning the lives of two families from as far back as the 1800s and India to late 1990s Willesden.",
#    'poster_path': '/q4ORxxzAnBb7RE3pdw5ToAGViHu.jpg',
#    'release_date': '2002-09-16',
#    'title': 'White Teeth',
#    'video': False,
#    'vote_average': 6.6,
#    'vote_count': 5,
#    'popularity': 1.301,
#    'character': 'Josh Malfen',
#    'credit_id': '537687710e0a26141f0000ba',
#    'order': 4},
#   {'adult': False,
#    'backdrop_path': '/tuDhEdza074bA497bO9WFEPs6O6.jpg',
#    'genre_ids': [12, 10751, 14],
#    'original_language': 'en',
#    'original_title': 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#    'poster_path': '/kzJip9vndXYSKQHCgekrgqbnUrA.jpg',
#    'video': False,
#    'vote_average': 7.1,
#    'vote_count': 8197,
#    'overview': "Siblings Lucy, Edmund, Susan and Peter step through a magical wardrobe and find the land of Narnia. There, they discover a charming, once peaceful kingdom that has been plunged into eternal winter by the evil White Witch, Jadis. Aided by the wise and magnificent lion, Aslan, the children lead Narnia into a spectacular, climactic battle to be free of the Witch's glacial powers forever.",
#    'release_date': '2005-12-07',
#    'title': 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#    'id': 411,
#    'popularity': 95.618,
#    'character': 'Mr. Tumnus',
#    'credit_id': '52fe4240c3a36847f800fcdd',
#    'order': 5},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'id': 852532,
#    'original_language': 'en',
#    'original_title': 'The Gruffalo and Me: The Remarkable Julia Donaldson',
#    'overview': "The programme offers unique access to Julia Donaldson, her family, her rich archives and home movies, and the remarkable cast of characters that have sprung from her imagination. Specially commissioned animations from Julia's long-term illustrator Axel Scheffler bring her biography to life. With contributions from well-known admirers and collaborators, this is a tribute to the woman who has created the characters and stories that have become a fixture of children’s bedtime routines all around the world and spawned multi-award-winning adaptations for stage and screen.  Looking at her works, the programme uncovers the surprising stories behind how Julia's iconic characters were created and what they mean to a generation of readers. It also explores why Donaldson’s books appeal to both children and adults alike – tackling serious themes of love, loss, fear and bullying in a poignant but subtle way.",
#    'poster_path': None,
#    'release_date': '2020-12-25',
#    'title': 'The Gruffalo and Me: The Remarkable Julia Donaldson',
#    'video': False,
#    'vote_average': 0.0,
#    'vote_count': 0,
#    'popularity': 0.898,
#    'character': 'reader',
#    'credit_id': '60f73e02209f180044bb025e',
#    'order': 6},
#   {'backdrop_path': None,
#    'genre_ids': [18, 53],
#    'original_language': 'en',
#    'original_title': 'The Near Room',
#    'poster_path': '/zJVUq9li8XB7uY3VmXyNKApmtsL.jpg',
#    'title': 'The Near Room',
#    'vote_average': 6.6,
#    'vote_count': 5,
#    'overview': "Charlie Colquhoun is a journalist whose career is floundering. As a teenager, he fathered a daughter, Tommy, who was committed to foster care as an infant. Seventeen years later, Charlie, Tommy and Charlie's old schoolmate Harris Hill, now a squeaky-clean solicitor, are reunited by a scandal that includes child pornography, blackmail and murder.",
#    'release_date': '1995-08-20',
#    'id': 184716,
#    'video': False,
#    'adult': False,
#    'popularity': 0.853,
#    'character': 'Kevin',
#    'credit_id': '52fe4cc69251416c751253bf',
#    'order': 7},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [],
#    'id': 691677,
#    'original_language': 'en',
#    'original_title': 'X-Men: First Class 35mm Special',
#    'overview': "In the 1960s, superpowered humans Charles Xavier and Erik Lensherr work together to find others like them, but Erik's vengeful pursuit of an ambitious mutant who ruined his life causes a schism to divide them",
#    'poster_path': '/rtuSk6E5RF30yM7P0mqnyDdYYl4.jpg',
#    'release_date': '2011-05-27',
#    'title': 'X-Men: First Class 35mm Special',
#    'video': False,
#    'vote_average': 8.0,
#    'vote_count': 2,
#    'popularity': 8.953,
#    'character': '',
#    'credit_id': '611c2f77ca83540047331ddc',
#    'order': 7},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'id': 447162,
#    'original_language': 'en',
#    'original_title': 'X-Men: Unguarded',
#    'overview': "The film's all-star ensemble cast joins director Bryan Singer and screenwriter Simon Kinberg to share their favorite stories from the set.",
#    'poster_path': None,
#    'release_date': '2015-07-14',
#    'title': 'X-Men: Unguarded',
#    'video': True,
#    'vote_average': 7.5,
#    'vote_count': 16,
#    'popularity': 5.366,
#    'character': 'Self',
#    'credit_id': '58c990e59251415e850015a1',
#    'order': 9},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [10751],
#    'id': 320924,
#    'original_language': 'en',
#    'original_title': 'Angelina Ballerina: The Mouseling Mysteries',
#    'overview': 'Put on your detective cap and search for the clues with Angelina in The Mouseling Mysteries! Something suspicious is going on in Chipping Cheddar: Gracie fears Roquefort Hall is haunted when she hears strange sounds, Marco’s music goes missing and Mr. Chirpyface disappears while Angelina is bird sitting for Ms. Mimi! Can Angelina and her friends stay en pointe and follow the clues to solve these mysteries? Join the fun and gather the evidence with Camembert’s star detectives!',
#    'poster_path': '/dWAS02y627hUOalmEyeY3enaKdQ.jpg',
#    'release_date': '2013-03-12',
#    'title': 'Angelina Ballerina: The Mouseling Mysteries',
#    'video': True,
#    'vote_average': 10.0,
#    'vote_count': 1,
#    'popularity': 1.508,
#    'character': 'Mr. Mouseling',
#    'credit_id': '6172fb06894ed6008e431c17',
#    'order': 9},
#   {'adult': False,
#    'backdrop_path': '/nXXhswchGwLP13zj5C2f8PA3X3P.jpg',
#    'genre_ids': [99],
#    'id': 661286,
#    'original_language': 'en',
#    'original_title': 'The Summers of IT: Chapter One',
#    'overview': 'This documentary focuses on the actors and their journey over two summers to create the remake to the original IT, by Stephen King. The documentary originally released as bonus material, bundled with IT: Chapter Two.',
#    'poster_path': '/7l6r0zevn39WFKkESeHKFcDIDeZ.jpg',
#    'release_date': '2019-12-10',
#    'title': 'The Summers of IT: Chapter One',
#    'video': False,
#    'vote_average': 9.0,
#    'vote_count': 8,
#    'popularity': 4.194,
#    'character': 'Himself',
#    'credit_id': '5e12aed58741c400123d6867',
#    'order': 10},
#   {'adult': False,
#    'backdrop_path': '/nXXhswchGwLP13zj5C2f8PA3X3P.jpg',
#    'genre_ids': [27, 18, 14],
#    'id': 661289,
#    'original_language': 'en',
#    'original_title': 'The Summers of IT: Chapter Two',
#    'overview': 'This documentary focuses on the actors and their journey over two summers to create the remake to the original IT, by Stephen King. The documentary originally released as bonus material, bundled with IT: Chapter Two.',
#    'poster_path': '/tNyUIYsTLtMql2SvQvvGZvWsd23.jpg',
#    'release_date': '2019-12-10',
#    'title': 'The Summers of IT: Chapter Two',
#    'video': False,
#    'vote_average': 7.7,
#    'vote_count': 35,
#    'popularity': 8.058,
#    'character': 'Self',
#    'credit_id': '5e12b2a08741c400123d7712',
#    'order': 11},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [18, 10749],
#    'id': 58458,
#    'original_language': 'en',
#    'original_title': 'Lorna Doone',
#    'overview': "The year is 1675. England is threatened by religious and political rivalries. King Charles II's Catholic brother, James, is next in line for the throne, but many Protestants put their faith in Charles' illegitimate son, The Duke of Monmouth. On the king's death, conflict is inevitable... Over seven days journey from London, Exmoor is a primitive and lawless area. Here, farmer Jack Ridd lives with his wife Sarah, son John, and two daughters. The only shadow over their simple life is cast by the notorious outlaw family the Doones. The aristocratic Doones were banished from their ancestral lands and now live through looting, theft, and murder. Their brutality is legendary...",
#    'poster_path': '/nXutrOOS8dMJI6CbnZ6Q1HqLrSJ.jpg',
#    'release_date': '2001-03-11',
#    'title': 'Lorna Doone',
#    'video': False,
#    'vote_average': 5.7,
#    'vote_count': 17,
#    'popularity': 4.158,
#    'character': 'Sergeant Bloxham',
#    'credit_id': '587ce4329251413eec019858',
#    'order': 18},
#   {'adult': False,
#    'backdrop_path': '/hxFV3YybhyGhyebUl6ZMBvGWvt0.jpg',
#    'genre_ids': [18, 10752],
#    'id': 49798,
#    'original_language': 'en',
#    'original_title': 'Regeneration',
#    'overview': "Wilfred Owen and Siegfried Sassoon, two of England's most important World War I poets are sent, along with other traumatized combatants, to a rest home in order to treat their emotional troubles, caused by the psychological fatigue that suffer the soldiers fighting in the no man's land.",
#    'poster_path': '/jWNif4E8ZRhqRBItr0FWVMz1ooO.jpg',
#    'release_date': '1997-08-27',
#    'title': 'Regeneration',
#    'video': False,
#    'vote_average': 6.1,
#    'vote_count': 19,
#    'popularity': 2.646,
#    'character': 'Anthony Balfour',
#    'credit_id': '587ce406925141410100ef98',
#    'order': 20},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'id': 547562,
#    'original_language': 'en',
#    'original_title': 'Killers Kill, Dead Men Die',
#    'overview': "The most ambitious portfolio in the 13-year history of Vanity Fair's Hollywood Issue, this year's homage to noir had its own dramatic imperatives.",
#    'poster_path': '/wgyOGEkkOU71izGCwLiuIgfmjtD.jpg',
#    'release_date': '2007-03-13',
#    'title': 'Killers Kill, Dead Men Die',
#    'video': True,
#    'vote_average': 4.3,
#    'vote_count': 9,
#    'popularity': 2.827,
#    'character': 'The Shutterbug',
#    'credit_id': '5b96b5c5c3a36856760377b6',
#    'order': 24},
#   {'adult': False,
#    'backdrop_path': '/5ZSwZPKgcTJJwhxjbOHeoBTVaKh.jpg',
#    'genre_ids': [35, 28],
#    'id': 567604,
#    'original_language': 'en',
#    'original_title': 'Once Upon a Deadpool',
#    'overview': "A kidnapped Fred Savage is forced to endure Deadpool's PG-13 rendition of Deadpool 2 as a Princess Bride-esque story that's full of magic, wonder & zero F's.",
#    'poster_path': '/5Ka49BWWyKMXr93YMbH5wLN7aAM.jpg',
#    'release_date': '2018-12-11',
#    'title': 'Once Upon a Deadpool',
#    'video': False,
#    'vote_average': 7.1,
#    'vote_count': 537,
#    'popularity': 46.317,
#    'character': 'Charles Xavier / Professor X',
#    'credit_id': '5c22b0ff0e0a264df2f04f78',
#    'order': 24},
#   {'adult': False,
#    'backdrop_path': '/i1bWTYcIEcVEkgL9WMwM2h5n8fz.jpg',
#    'genre_ids': [35, 12, 80, 10751],
#    'id': 145220,
#    'original_language': 'en',
#    'original_title': 'Muppets Most Wanted',
#    'overview': 'While on a grand world tour, The Muppets find themselves wrapped into an European jewel-heist caper headed by a Kermit the Frog look-alike and his dastardly sidekick.',
#    'poster_path': '/3NaHGIsgyIIbf9EuediU75QnJye.jpg',
#    'release_date': '2014-03-20',
#    'title': 'Muppets Most Wanted',
#    'video': False,
#    'vote_average': 6.3,
#    'vote_count': 661,
#    'popularity': 17.291,
#    'character': 'UPS Guy',
#    'credit_id': '5470661cc3a36828e0000dc1',
#    'order': 27},
#   {'video': False,
#    'vote_average': 7.5,
#    'overview': "Wisecracking mercenary Deadpool battles the evil and powerful Cable and other bad guys to save a boy's life.",
#    'release_date': '2018-05-10',
#    'adult': False,
#    'backdrop_path': '/3P52oz9HPQWxcwHOwxtyrVV1LKi.jpg',
#    'vote_count': 13881,
#    'genre_ids': [28, 35, 12],
#    'title': 'Deadpool 2',
#    'original_language': 'en',
#    'original_title': 'Deadpool 2',
#    'poster_path': '/to0spRl1CMDvyUbOnbb4fTk3VAd.jpg',
#    'id': 383498,
#    'popularity': 116.927,
#    'character': 'Charles Xavier (uncredited)',
#    'credit_id': '5dff991126dac1001762a68f',
#    'order': 62},
#   {'overview': 'A global broadcast & digital special organized by Global Citizen and the World Health Organization featuring comedians, musicians, and actors to raise funds in support of front line health workers in the global response to COVID-19.',
#    'release_date': '2020-04-18',
#    'title': 'One World: Together at Home',
#    'id': 694527,
#    'adult': False,
#    'backdrop_path': '/vGYlunWBrMUsPAhjkRpy0GCnIEL.jpg',
#    'genre_ids': [10402],
#    'original_language': 'en',
#    'original_title': 'One World: Together at Home',
#    'poster_path': '/tOvv28PSM04AerehwigqdeSdlmC.jpg',
#    'video': False,
#    'vote_average': 7.3,
#    'vote_count': 24,
#    'popularity': 6.028,
#    'character': 'Self',
#    'credit_id': '60d63d0fef9d72005d9f4fbe',
#    'order': 115}],
#  'crew': [{'genre_ids': [35, 18],
#    'original_language': 'en',
#    'original_title': '50/50',
#    'poster_path': '/aZ3JKeCV4EmprxrbzIDuyb7M7AZ.jpg',
#    'video': False,
#    'id': 40807,
#    'overview': 'Inspired by a true story, a comedy centered on a 27-year-old guy who learns of his cancer diagnosis and his subsequent struggle to beat the disease.',
#    'release_date': '2011-09-30',
#    'title': '50/50',
#    'vote_count': 3007,
#    'adult': False,
#    'backdrop_path': '/yq9g4RGM1mEMBoSL5HKVBy9MOPM.jpg',
#    'vote_average': 7.1,
#    'popularity': 33.766,
#    'credit_id': '57d0471e92514173a9000ed0',
#    'department': 'Crew',
#    'job': 'Thanks'},
#   {'overview': 'A bigoted junkie cop suffering from bipolar disorder and drug addiction manipulates and hallucinates his way through the festive season in a bid to secure promotion and win back his wife and daughter.',
#    'release_date': '2013-09-23',
#    'adult': False,
#    'backdrop_path': '/wpl0kQvawRlaH7l68SoIAAyOmgV.jpg',
#    'genre_ids': [80, 18, 35],
#    'vote_count': 1315,
#    'original_language': 'en',
#    'id': 85889,
#    'poster_path': '/opejdaSr1Fl6JoCMmuu2LpKvpdR.jpg',
#    'title': 'Filth',
#    'video': False,
#    'vote_average': 6.9,
#    'original_title': 'Filth',
#    'popularity': 11.579,
#    'credit_id': '52fe49659251416c910abe8d',
#    'department': 'Production',
#    'job': 'Producer'}],
#  'id': 5530}

# %%
api_key = "016a99e06e5f2bae86de7daf408c7692"
api_link = "https://api.themoviedb.org/3"
params = {'query':"Tom Cruise" , 'api_key':api_key}
header = {'Accept': 'application/json'}
response = requests.get(api_link + "/search/person/", headers = header, params = params,verify=False)
data = response.json()
results = data.get('results')
for result in results:
    if result.get('name') == 'Tom Cruise':
        id = result.get('id')

params2 = {'api_key':api_key}
response2 = requests.get(api_link + "/person/" + str(id) + "/movie_credits" , headers = header, params = params2,verify=False)
data2 = response2.json()
cast_result = data2.get('cast')
for cast in cast_result:
    if cast.get('original_title') == "Top Gun":
        print(cast.get('character'))
for cast in cast_result:
    if cast.get('original_title') == "Mission: Impossible - Fallout":
        print(cast.get('character'))
for cast in cast_result:
    if cast.get('original_title') == "Minority Report":
        print(cast.get('character'))
for cast in cast_result:
    if cast.get('original_title') == "Edge of Tomorrow":
        print(cast.get('character'))
# Out:
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
import requests
api_key = "e226f4a5f5bace766952aa0d17182959" 
api_link = "https://api.themoviedb.org/3" #/movie/top_rated/apikey = 
header = {'Accept': 'application/json'} 
params = {'api_key':api_key, 'region':'US'} 
response = requests.get(api_link + "/movie/top_rated", headers = header, params = params,verify=False) 


data = response.json() 
results = data.get('results') 
title_array = [] 
genre_id_array = [] 
for result in results: 
    if result.get('original_language') == 'en': 
        title_array.append(result.get('title')) 
        genre_id_array.append(result.get('genre_ids')) 
        
# To get the genre name corresponding to genre_id 
response2 = requests.get(api_link + "/genre/movie/list", headers = header, params = params,verify=False) 
data2 = response2.json() 
genres = data2.get('genres') 
mapping = {} 
for genre in genres: 
    mapping[genre.get('id')] = genre.get('name') 
    
for i in range(10): 
    print(title_array[i], "-", end=" ") 
    for id in genre_id_array[i]: 
        print(mapping.get(id), end = ", ") 
    print()
# Out:
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# The Shawshank Redemption - Drama, Crime,
# The Godfather - Drama, Crime,
# Gabriel's Inferno Part II - Romance,
# Gabriel's Inferno Part III - Romance, Comedy,
# Gabriel's Inferno - Romance,
# Schindler's List - Drama, History, War,
# The Godfather: Part II - Drama, Crime,
# Wolfwalkers - Animation, Family, Adventure, Fantasy,
# The Green Mile - Fantasy, Drama, Crime,
# 12 Angry Men - Drama,

# %%
api_key = "e226f4a5f5bace766952aa0d17182959" 
api_link = "https://api.themoviedb.org/3" 
params = {'query':'Money Heist','api_key':api_key} 
header = {'Accept': 'application/json'} 
response = requests.get(api_link + '/search/tv/', headers = header, params = params,verify=False) 
data = response.json() 
data
# result=data.get('results')
# for i in result:
#     if i.get('name')=='Money Heist':
#         id=i.get('id')    
# params1={'id':id,'api_key':api_key}
# print(id)
# response1 = requests.get(api_link + '/tv/' + str(id) + '/credits', headers = header, params = params1,verify=False) 
# data1 = response1.json() 
# cast=data1.get('cast')
# count_male=0
# count_female=0
# for c in cast:
#     if c.get('gender')==1:
#         count_female+=1
#     if c.get('gender')==2:
#         count_male+=1
# print(count_male,count_female)
# response.json()
# Out:
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'page': 1,
#  'results': [{'backdrop_path': '/gFZriCkpJYsApPZEF3jhxL4yLzG.jpg',
#    'first_air_date': '2017-05-02',
#    'genre_ids': [80, 18],
#    'id': 71446,
#    'name': 'Money Heist',
#    'origin_country': ['ES'],
#    'original_language': 'es',
#    'original_name': 'La Casa de Papel',
#    'overview': 'To carry out the biggest heist in history, a mysterious man called The Professor recruits a band of eight robbers who have a single characteristic: none of them has anything to lose. Five months of seclusion - memorizing every step, every detail, every probability - culminate in eleven days locked up in the National Coinage and Stamp Factory of Spain, surrounded by police forces and with dozens of hostages in their power, to find out whether their suicide wager will lead to everything or nothing.',
#    'popularity': 598.849,
#    'poster_path': '/reEMJA1uzscCbkpeRJeTT2bjqUp.jpg',
#    'vote_average': 8.3,
#    'vote_count': 14868},
#   {'backdrop_path': '/bVUiZVA8iPwdEc0lX5nwEr6MwdM.jpg',
#    'first_air_date': '2021-09-03',
#    'genre_ids': [99],
#    'id': 132719,
#    'name': 'Money Heist: From Tokyo to Berlin',
#    'origin_country': ['ES'],
#    'original_language': 'es',
#    'original_name': 'La Casa de Papel: de Tokio a Berlín',
#    'overview': 'The filmmakers and actors behind "Money Heist" characters like Tokyo and the Professor talk about the emotional and artistic process of filming Money Heist.',
#    'popularity': 137.703,
#    'poster_path': '/g0wLsOFpvK5nX5hsIAwXHrpnFLI.jpg',
#    'vote_average': 7.3,
#    'vote_count': 17},
#   {'backdrop_path': None,
#    'first_air_date': '',
#    'genre_ids': [18],
#    'id': 112836,
#    'name': 'Money Heist',
#    'origin_country': ['KR'],
#    'original_language': 'ko',
#    'original_name': '종이의 집',
#    'overview': 'A criminal mastermind, who goes by the nickname "The Professor", has a plan to pull off the biggest heist in recorded history.\n\nThe Professor schemes an ambitious heist that will have a massive payout. For his plan, the Professor scouts for potential team members. The recruited members select city names as their code names and they all have strong personalities. Their plan seems perfect, but due to the hostages that they take, they face an unexpected situation.',
#    'popularity': 1.278,
#    'poster_path': '/s5eEB4VAvaQTLhQjrd2lGvk5yRG.jpg',
#    'vote_average': 0,
#    'vote_count': 0}],
#  'total_pages': 1,
#  'total_results': 3}

# %%
param ={'api_key':'e226f4a5f5bace766952aa0d17182959','query':'Money Heist'}
r = requests.get('https://api.themoviedb.org/3/search/tv',verify=False,params=param)
id = r.json()['results'][0]['id']
print(r.json())
r = requests.get('https://api.themoviedb.org/3/tv/'+str(id)+'/credits',params=param,verify=False)
m = 0
f = 0
for i in r.json()['cast']:
    if i['gender'] ==2:
        m+=1
    if i['gender'] == 1:
        f+=1
print(m,end=' ')
print(f)
# Out:
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'page': 1, 'results': [{'backdrop_path': '/gFZriCkpJYsApPZEF3jhxL4yLzG.jpg', 'first_air_date': '2017-05-02', 'genre_ids': [80, 18], 'id': 71446, 'name': 'Money Heist', 'origin_country': ['ES'], 'original_language': 'es', 'original_name': 'La Casa de Papel', 'overview': 'To carry out the biggest heist in history, a mysterious man called The Professor recruits a band of eight robbers who have a single characteristic: none of them has anything to lose. Five months of seclusion - memorizing every step, every detail, every probability - culminate in eleven days locked up in the National Coinage and Stamp Factory of Spain, surrounded by police forces and with dozens of hostages in their power, to find out whether their suicide wager will lead to everything or nothing.', 'popularity': 598.849, 'poster_path': '/reEMJA1uzscCbkpeRJeTT2bjqUp.jpg', 'vote_average': 8.3, 'vote_count': 14868}, {'backdrop_path': '/bVUiZVA8iPwdEc0lX5nwEr6MwdM.jpg', 'first_air_date': '2021-09-03', 'genre_ids': [99], 'id': 132719, 'name': 'Money Heist: From Tokyo to Berlin', 'origin_country': ['ES'], 'original_language': 'es', 'original_name': 'La Casa de Papel: de Tokio a Berlín', 'overview': 'The filmmakers and actors behind "Money Heist" characters like Tokyo and the Professor talk about the emotional and artistic process of filming Money Heist.', 'popularity': 137.703, 'poster_path': '/g0wLsOFpvK5nX5hsIAwXHrpnFLI.jpg', 'vote_average': 7.3, 'vote_count': 17}, {'backdrop_path': None, 'first_air_date': '', 'genre_ids': [18], 'id': 112836, 'name': 'Money Heist', 'origin_country': ['KR'], 'original_language': 'ko', 'original_name': '종이의 집', 'overview': 'A criminal mastermind, who goes by the nickname "The Professor", has a plan to pull off the biggest heist in recorded history.\n\nThe Professor schemes an ambitious heist that will have a massive payout. For his plan, the Professor scouts for potential team members. The recruited members select city names as their code names and they all have strong personalities. Their plan seems perfect, but due to the hostages that they take, they face an unexpected situation.', 'popularity': 1.278, 'poster_path': '/s5eEB4VAvaQTLhQjrd2lGvk5yRG.jpg', 'vote_average': 0, 'vote_count': 0}], 'total_pages': 1, 'total_results': 3}
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 11 6
