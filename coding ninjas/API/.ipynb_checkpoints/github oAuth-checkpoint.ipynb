# %%
#https://docs.github.com/en/developers/apps/building-oauth-apps/scopes-for-oauth-apps
#App ID: 149984

#Client ID: Iv1.0b5731403b49e687
# email id sumitdimshu@gmail.com
# client secret 65fc41644de82bb88980a2eecacb8e729ecb3ad6
import requests
import json

# %%
data = {'client_id':'Iv1.0b5731403b49e687','response_type':'code','state':'random_123','redirect_uri':'https://www.google.com/','scope':'admin:org'}
response = requests.get('https://github.com/login/oauth/authorize',params=data,verify=False)
print(response.url)
# Out:
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# https://github.com/login?client_id=Iv1.0b5731403b49e687&return_to=%2Flogin%2Foauth%2Fauthorize%3Fclient_id%3DIv1.0b5731403b49e687%26redirect_uri%3Dhttps%253A%252F%252Fwww.google.com%252F%26response_type%3Dcode%26scope%3Dadmin%253Aorg%26state%3Drandom_123

# %%
data = {'client_id':'Iv1.0b5731403b49e687','client_secret':'65fc41644de82bb88980a2eecacb8e729ecb3ad6',
        'code':'ac91207d2d9e8a8ad328','redirect_uri':'https://www.google.com/'}

response = requests.post('https://github.com/login/oauth/access_token',verify=False,data=data
                        ,headers={'User-Agent':'sumitdimshu'})
print(response.text)
# Out:
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# access_token=ghu_JQtBriFqfevi3RS8q5AC4fknCUexEQ1qpfov&expires_in=28800&refresh_token=ghr_PqXKBgMN1jzfCKpay5YIS1tgSh2zcnBKq7BWwEAA0gJrjl0kwK2EzHKDpUNWggJNItLmgh38majU&refresh_token_expires_in=15638400&scope=&token_type=bearer

# %%
## default Access token ghu_vJUZFf4jefEK9CnDwEplxkiRyi2qGi2N5ify
# admin:org ghu_JQtBriFqfevi3RS8q5AC4fknCUexEQ1qpfov

# %%
h = {'User-Agent':'sumitdimshu','Authorization':'bearer ghu_vJUZFf4jefEK9CnDwEplxkiRyi2qGi2N5ify'}
r = requests.get('https://api.github.com/orgs/CodingNinjasCodes/repos',headers=h,verify=False)
data = r.json()
for i in data:
    if i['fork'] == True:
        continue
    print(i['name'],end=' ')
    print(i['watchers_count'],end=' ')
    print(i['forks_count'])
# Out:
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# SmoothScrollJs 16 5
# RubyTutorial 14 9
# Python3Tutorial 5 3
# HTMLandCssNotes 15 23
# Beacathon 2 8
# JSNotes 5 9
# learnml 1 0
# RubyNotebook 2 5
# InterQues 71 162
# coderoom 4 3

# %%
h = {'User-Agent':'sumitdimshu','Authorization':'bearer ghu_JQtBriFqfevi3RS8q5AC4fknCUexEQ1qpfov'}
data = {'role':'admin'}
r = requests.put('https://api.github.com/orgs/sumitdimshu-coding-ninja/memberships/sumitdimshu',headers=h,verify=False,data=data)
r.json()
# Out:
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'message': 'You must be an admin to add or update an organization membership.',
#  'documentation_url': 'https://docs.github.com/rest/reference/orgs#set-organization-membership-for-a-user'}

# %%
h = {'User-Agent':'sumitdimshu','Authorization':'bearer ghu_JQtBriFqfevi3RS8q5AC4fknCUexEQ1qpfov'}
data = {'name':'DataScience API'}
r = requests.get('https://api.github.com/orgs/CodingNinjasCodes/members',headers=h,verify=False,data=data)
for i in r.json():
    print(i['login'])
# Out:
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 7534680
# 43447509
# 8034683
# 20709985
# 6631534
# 6624213

# %%
h = {'User-Agent':'sumitdimshu','Authorization':'bearer ghu_JQtBriFqfevi3RS8q5AC4fknCUexEQ1qpfov'}
r = requests.get('https://api.github.com/repos/CodingNinjasCodes/JSNotes/commits',headers=h,verify=False)
d = {}
for i in r.json():
    print(i['sha'],end=' ')
    print(i['committer']['login'])
# for i in r.json():
#     d[i['author']['login']] = d.get(i['author']['login'],0) + 1
# for i in d.keys():
#     print(i,end=' ')
#     print(d[i])
# for i in r.json():
#     print(i['login'],end = ' ')
#     print(i['contributions'])
# Out:
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 6e42c2d4051068dae3516c287c53569621086d7a tushartuteja
# 0f31e911212dd68ca045b86ae4d9ee282c316c5e web-flow
# e0104a4592295cb7bcd024f496475c5fb76efe38 web-flow
# 7e0a8dbb152605f8ad8728b2535b89bb190cac65 Sherawat42
# c5290143973ebfbaf7a48926eb5ec7a92b8f8348 Sherawat42
# 4ee81b2ebdc26264723392c81ba106d37a3e6a5d Sherawat42
# 57df9b3a943acf8f99668cf65d9b3bbbeff5632c Sherawat42
# 954101989c9bafaf11c5de7fd300253ac8bb199f Sherawat42
# 20136015022de2a65cfeb714e08dedd9573f9758 Rawal27
# a2309c10f339f3d93be41ad00a482a0ce2cd2104 Rawal27
# f527cc5289dbf8371032cd2fe62bc8be4a287e53 Rawal27
# bcfe1616a1227a825d82ba26a7bfa3a8343929ae Sherawat42
# ...

# %%
h = {'User-Agent':'sumitdimshu','Authorization':'bearer ghu_JQtBriFqfevi3RS8q5AC4fknCUexEQ1qpfov'}
r = requests.get('https://api.github.com/repos/CodingNinjasCodes/JSNotes/community/profile',headers=h,verify=False)
print(r.json()['health_percentage'])
# Out:
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 0

# %%
import requests
import json
h = {'User-Agent':'sumitdimshu','Authorization':'bearer ghu_vJUZFf4jefEK9CnDwEplxkiRyi2qGi2N5ify'}
r = requests.get('https://api.github.com/orgs/fossasia/repos',headers=h,verify=False)
data = r.json()
data
# for i in data:
#     print(i['name'])
# Out:
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# [{'id': 4132843,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MTMyODQz',
#   'name': 'x-mario',
#   'full_name': 'fossasia/x-mario',
#   'private': False,
#   'owner': {'login': 'fossasia',
#    'id': 6295529,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYyOTU1Mjk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6295529?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fossasia',
#    'html_url': 'https://github.com/fossasia',
#    'followers_url': 'https://api.github.com/users/fossasia/followers',
#    'following_url': 'https://api.github.com/users/fossasia/following{/other_user}',
# ...

# %%
import requests
import json
h = {'User-Agent':'sumitdimshu','Authorization':'bearer ghu_JQtBriFqfevi3RS8q5AC4fknCUexEQ1qpfov'}
r = requests.get('https://api.github.com/repos/CodingNinjasCodes/JSNotes/stats/contributors',headers=h,verify=False)
for i in r.json():
    print(i['author']['login'],end=' ')
    print(i['total'])
# d = {}
# for i in r.json():
#     d[i['author']['login']] = d.get(i['author']['login']['total'],0) + 1
# for i in d.keys():
#     print(i,end=' ')
#     print(d[i])
# Out:
# /Users/skumar6/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Sherawat42 15
# tushartuteja 5
# Rawal27 13
